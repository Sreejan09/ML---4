# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreejan09/ML---4/blob/main/kd_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install binarytree
# !pip install pandas
# Out:
# Requirement already satisfied: binarytree in /usr/local/lib/python3.10/dist-packages (6.5.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from binarytree) (0.20.3)
# Requirement already satisfied: setuptools>=60.8.2 in /usr/local/lib/python3.10/dist-packages (from binarytree) (75.1.0)
# Requirement already satisfied: setuptools-scm>=5.0.1 in /usr/local/lib/python3.10/dist-packages (from setuptools-scm[toml]>=5.0.1->binarytree) (8.1.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from setuptools-scm>=5.0.1->setuptools-scm[toml]>=5.0.1->binarytree) (24.2)
# Requirement already satisfied: tomli>=1 in /usr/local/lib/python3.10/dist-packages (from setuptools-scm>=5.0.1->setuptools-scm[toml]>=5.0.1->binarytree) (2.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from binarytree import tree, Node
from math import floor
import numpy as np

# %%
def distance(point1, point2):
    return np.linalg.norm(point1 - point2)

# %%
from math import floor
import numpy as np
import pandas as pd

class MyNode:
    def __init__(self, _id, data, axis, idx):
        self._id = _id
        self.data = data
        self.axis = axis
        self.idx = idx
        self.left = None
        self.right = None

class KD_Tree:
    def __init__(self, data):
        self.data = data
        self.tree = None

    def _build(self, points, depth):
        k = len(points.columns)
        _axis = depth % k
        _column = points.columns[_axis]

        if len(points) == 0:
            return None

        objects_list = points.sort_values(by=[_column], ascending=True)

        if len(objects_list) % 2 == 0:
            median_idx = int((len(objects_list) / 2))
        else:
            median_idx = floor((len(objects_list) / 2))

        node = MyNode(_id=round(objects_list.iloc[median_idx][_column], 3),
                      data=objects_list.iloc[median_idx],
                      axis=_column,
                      idx=median_idx)

        if len(objects_list) <= 40:
            return node  # Stop further branching if number of data points is 40 or fewer

        node.left = self._build(objects_list.iloc[0:median_idx], depth + 1)
        node.right = self._build(objects_list.iloc[median_idx + 1:], depth + 1)

        return node

    def build(self):
        self.tree = self._build(self.data, depth=0)

    def _nearest(self, query, node, best_node, best_distance):
        if not node:
            return best_node, best_distance

        d = distance(query.values[0], node.data.values)

        if d < best_distance:
            best_node = node
            best_distance = d
            print("best Node: {}".format(best_node.data.values))

        if query[node.axis].values[0] < node.data[node.axis]:
            good_side = node.left
            bad_side = node.right
        else:
            bad_side = node.left
            good_side = node.right

        best_node, best_distance = self._nearest(query, good_side, best_node, best_distance)

        if abs(node.data[node.axis] - query[node.axis].values[0]) < best_distance:
            best_node, best_distance = self._nearest(query, bad_side, best_node, best_distance)

        return best_node, best_distance

    def get_nn(self, query):
        return self._nearest(query, self.tree, None, np.inf)

# %%
import numpy as np
import pandas as pd

def generate_dataset(N, D):
    # Generate random values
    random_values = np.random.rand(N, D)
    # Round the values to two decimal places
    rounded_values = np.round(random_values, 2)
    # Create DataFrame from rounded values
    return pd.DataFrame(rounded_values, columns=[f"X{i}" for i in range(D)])

# %%
def measure_time_and_memory(N_values, D_values, KD_tree, k):
    training_times = []
    testing_times = []
    memory_usage = []

    for N in N_values:
        for D in D_values:
            # Generate random dataset
            dataset = generate_dataset(N, D)
            query_point = pd.DataFrame(np.random.rand(1, D), columns=[f"X{i}" for i in range(D)])

            # Build KD Tree
            KD = KD_tree(dataset)
            start_time = time.time()
            KD.build()
            end_time = time.time()
            training_time = end_time - start_time

            # Measure testing time
            start_time = time.time()
            KD.get_nn(query_point)
            end_time = time.time()
            testing_time = end_time - start_time

            # Measure memory usage
            process = psutil.Process()
            process_memory = process.memory_info().rss
            memory_usage.append(process_memory)

            # Append to lists
            training_times.append(training_time)
            testing_times.append(testing_time)

    return training_times, testing_times, memory_usage

# %%
import time
import psutil  # For memory usage
import matplotlib.pyplot as plt

# %%
# Define parameters
#N_values = np.random.randint(low=100, high=1000, size=50)  # Varying dataset sizes
N_values = np.sort(np.random.randint(low=100, high=5000, size=50))
D_values = [2, 3, 5, 7, 9, 10]  # Varying number of dimensions
k = 5  # Number of nearest neighbors

# Measure time and memory
training_times, testing_times, memory_usage = measure_time_and_memory(N_values, D_values, KD_Tree, k)

# Plot results
plt.figure(figsize=(10, 6))

# Plot training time
plt.subplot(2, 1, 1)
for i, D in enumerate(D_values):
    plt.plot(N_values, training_times[i * len(N_values):(i + 1) * len(N_values)], marker='o', label=f"D={D}")
plt.title('Training Time vs Dataset Size')
plt.xlabel('Dataset Size (N)')
plt.ylabel('Training Time (s)')
plt.legend()
# Plot testing time
plt.subplot(2, 1, 2)
for i, D in enumerate(D_values):
    plt.plot(N_values, testing_times[i * len(N_values):(i + 1) * len(N_values)], marker='o', label=f"D={D}")
plt.title('Testing Time vs Dataset Size')
plt.xlabel('Dataset Size (N)')
plt.ylabel('Testing Time (s)')
plt.legend()

plt.tight_layout()
plt.show()

# Plot memory usage
plt.figure(figsize=(10, 6))
for i, D in enumerate(D_values):
    plt.plot(N_values, memory_usage[i * len(N_values):(i + 1) * len(N_values)], marker='o', label=f"D={D}")
plt.title('Memory Usage vs Dataset Size')
plt.xlabel('Dataset Size (N)')
plt.ylabel('Memory Usage (bytes)')
plt.legend()
plt.show()
# Out:
# best Node: [0.51 0.62]
# best Node: [0.17 0.46]
# best Node: [0.51 0.86 0.75]
# best Node: [0.9  0.63 0.44]
# best Node: [0.74 0.64 0.32]
# best Node: [0.51 0.8  0.34]
# best Node: [0.52 0.59 0.17 0.96 0.18]
# best Node: [0.48 0.54 0.17 0.32 0.44]
# best Node: [0.45 0.8  0.55 0.65 0.75]
# best Node: [0.52 0.79 0.23 0.49 0.36 0.83 0.02]
# best Node: [0.72 0.52 0.05 0.93 0.71 0.75 0.79]
# best Node: [0.52 0.64 0.23 0.58 0.65 0.69 0.78]
# best Node: [0.48 0.3  0.32 0.26 0.75 0.37 0.73 0.46 0.55]
# best Node: [0.52 0.54 0.39 0.31 0.25 0.34 0.46 0.19 0.22]
# best Node: [0.49 0.58 0.62 0.41 0.3  0.68 0.85 0.69 0.93]
# best Node: [0.52 0.89 0.59 0.92 0.55 0.51 0.22 0.54 0.14]
# best Node: [0.57 0.74 0.78 0.3  0.51 0.62 0.82 0.76 0.99]
# best Node: [0.55 0.74 0.34 0.45 0.1  0.07 0.46 0.3  0.61]
# best Node: [0.97 0.06 0.59 0.86 0.48 0.   0.24 0.32 0.97]
# best Node: [0.25 0.68 0.87 0.37 0.84 0.43 0.4  0.03 0.7 ]
# best Node: [0.48 0.29 0.6  0.72 0.45 0.87 0.52 0.14 0.62 0.46]
# best Node: [0.41 0.14 0.51 0.67 0.79 0.71 0.15 0.46 0.04 0.02]
# best Node: [0.02 0.13 0.5  0.46 0.71 0.09 0.64 0.62 0.23 0.54]
# best Node: [0.34 0.16 0.28 0.74 0.48 0.38 0.37 0.19 0.45 0.62]
# best Node: [0.23 0.19 0.62 0.78 0.57 0.23 0.04 0.62 0.13 0.34]
# best Node: [0.51 0.36 0.78 0.97 0.58 0.45 0.22 0.65 0.69 0.69]
# best Node: [0.5  0.14]
# best Node: [0.15 0.49]
# best Node: [0.15 0.52]
# best Node: [0.39 0.45]
# best Node: [0.52 0.35 0.32]
# best Node: [0.35 0.15 0.58]
# best Node: [0.46 0.19 0.58]
# best Node: [0.53 0.55 0.4  0.46 0.21]
# best Node: [0.31 0.48 0.92 0.42 0.22]
# best Node: [0.27 0.18 0.65 0.85 0.31]
# best Node: [0.56 0.35 0.84 0.53 0.03]
# best Node: [0.49 0.75 0.87 0.39 0.01 0.25 0.91]
# best Node: [0.02 0.5  0.51 0.05 0.24 0.83 0.46]
# best Node: [0.05 0.3  0.57 0.62 0.07 0.66 0.53]
# best Node: [0.5  0.81 0.65 0.64 0.02 0.32 0.94 0.13 0.73]
# best Node: [1.   0.61 0.1  0.42 0.07 0.29 0.34 0.85 0.84]
# best Node: [0.91 0.49 0.49 0.63 0.11 0.61 0.46 0.64 0.57]
# best Node: [0.83 0.26 0.24 0.57 0.57 0.22 0.59 0.35 0.64]
# best Node: [0.49 0.44 0.01 0.24 0.21 0.35 0.17 0.07 0.2  0.85]
# best Node: [0.89 0.62 0.49 0.46 0.74 0.52 0.11 0.14 0.36 0.07]
# best Node: [0.53 0.91]
# best Node: [0.91 0.42]
# best Node: [0.73 0.25]
# best Node: [0.53 0.23]
# best Node: [0.62 0.39]
# best Node: [0.48 0.57 0.19]
# best Node: [0.59 0.48 0.54]
# best Node: [0.64 0.07 0.34]
# best Node: [0.77 0.08 0.96]
# best Node: [0.92 0.27 0.57]
# best Node: [0.48 1.   0.33 0.12 0.02]
# best Node: [0.51 0.55 0.65 0.38 0.78]
# best Node: [0.51 0.71 0.68 0.5  0.34]
# best Node: [0.52 0.5  0.82 0.99 0.63]
# best Node: [0.49 0.62 0.01 0.78 0.95 0.67 0.85]
# best Node: [0.51 0.27 0.1  0.8  0.7  0.08 0.16 0.1  0.79]
# best Node: [0.95 0.36 0.01 0.55 0.91 0.12 0.59 0.73 0.13]
# best Node: [0.49 0.24 0.49 0.19 0.59 0.91 0.81 0.24 0.5 ]
# best Node: [0.54 0.38 0.33 0.12 0.34 0.47 0.67 0.26 0.9  0.48]
# best Node: [0.92 0.02 0.52 0.26 0.26 0.88 0.31 0.02 0.54 0.97]
# best Node: [0.81 0.43 0.25 0.42 0.16 0.89 0.07 0.35 0.56 0.87]
# best Node: [0.43 0.1  0.12 0.25 0.38 0.48 0.17 0.31 0.28 0.37]
# best Node: [0.49 0.75]
# best Node: [0.53 0.24 0.17]
# best Node: [0.89 0.5  0.99]
# best Node: [0.96 0.62 0.48]
# best Node: [0.7  0.71 0.67]
# best Node: [0.51 0.65 0.95 0.31 0.09]
# best Node: [0.32 0.51 0.67 0.65 0.75]
# best Node: [0.35 0.11 0.57 0.48 0.1 ]
# best Node: [0.42 0.39 0.37 0.53 0.13]
# best Node: [0.3  0.57 0.07 0.91 0.45]
# best Node: [0.53 0.32 0.78 0.46 0.01 0.32 0.46]
# best Node: [0.11 0.52 0.88 0.78 0.88 0.57 0.22]
# best Node: [0.46 0.8  0.45 0.22 0.43 0.49 0.01]
# best Node: [0.49 0.11 0.11 0.85 0.93 0.74 0.99 0.05 0.33]
# best Node: [0.04 0.49 0.18 0.45 0.04 0.98 0.65 0.69 0.51]
# best Node: [0.   0.75 0.36 0.19 0.44 0.2  0.87 0.8  0.86]
# best Node: [0.18 0.77 0.58 0.44 0.18 0.59 0.63 0.48 0.37]
# best Node: [0.48 0.71 0.29 0.38 0.26 0.29 0.01 0.51 0.47 0.36]
# best Node: [0.73 0.5  0.96 0.02 0.52 0.79 0.79 0.67 0.39 0.07]
# best Node: [0.35 0.03 0.65 0.6  0.95 0.4  0.93 0.76 0.29 0.02]
# best Node: [0.52 0.78]
# best Node: [0.64 0.48]
# best Node: [0.76 0.46]
# best Node: [0.95 0.27]
# best Node: [0.88 0.17]
# best Node: [0.81 0.14]
# best Node: [0.5  0.81 0.56]
# best Node: [0.17 0.51 0.83]
# best Node: [0.27 0.11 0.89]
# best Node: [0.5  0.93 0.61 0.77 0.02]
# best Node: [0.56 0.51 0.21 0.53 0.47]
# best Node: [0.83 0.74 0.56 0.74 0.32]
# best Node: [0.89 0.84 0.91 0.44 0.45]
# best Node: [0.55 0.71 0.68 0.27 0.46]
# best Node: [0.74 0.92 0.76 0.01 0.66]
# best Node: [0.48 0.35 0.59 0.45 0.47 0.22 0.79]
# best Node: [0.66 0.66 0.53 0.31 0.89 0.56 0.91]
# best Node: [0.87 0.88 0.79 0.38 0.91 0.44 0.79]
# best Node: [0.51 0.32 0.39 0.27 0.82 0.85 0.02 0.81 0.67]
# best Node: [0.47 0.66 0.93 0.14 0.53 0.61 0.83 0.84 0.66]
# best Node: [0.36 0.4  0.7  0.49 0.77 0.41 0.69 0.77 0.64]
# best Node: [0.52 0.49 0.67 0.43 0.92 0.85 0.82 0.28 0.98 0.52]
# best Node: [0.11 0.46 0.48 0.23 0.8  0.53 0.57 0.36 0.25 0.8 ]
# best Node: [0.46 0.28 0.15 0.52 0.28 0.54 0.08 0.8  0.95 0.63]
# best Node: [0.06 0.06 0.4  0.42 0.49 0.5  0.46 0.78 0.76 0.75]
# best Node: [0.53 0.83]
# best Node: [0.27 0.91]
# best Node: [0.16 0.75]
# best Node: [0.12 0.82]
# best Node: [0.49 0.47 0.38]
# best Node: [0.45 0.52 0.45]
# best Node: [0.34 0.2  0.42]
# best Node: [0.26 0.22 0.55]
# best Node: [0.35 0.3  0.68]
# best Node: [0.49 0.18 0.86 0.3  0.25]
# best Node: [0.77 0.5  0.47 0.3  0.32]
# best Node: [0.54 0.19 0.89 0.46 0.42]
# best Node: [0.61 0.02 0.86 0.9  0.62]
# best Node: [0.71 0.29 0.59 0.65 0.75]
# best Node: [0.5  0.64 0.65 0.45 0.35 0.44 0.58]
# best Node: [0.01 0.39 0.45 0.29 0.25 0.61 0.83]
# best Node: [0.35 0.14 0.24 0.57 0.44 0.45 0.43]
# best Node: [0.15 0.16 0.2  0.88 0.49 0.22 0.63]
# best Node: [0.51 0.58 0.7  0.58 0.56 0.   0.46 0.87 0.92]
# best Node: [0.39 0.54 0.02 0.48 0.82 0.3  0.27 0.77 0.32]
# best Node: [0.36 0.12 0.51 0.3  0.77 0.21 0.74 0.41 0.94]
# best Node: [0.29 0.16 0.42 0.85 0.37 0.11 0.94 0.64 0.3 ]
# best Node: [0.21 0.18 0.44 0.52 0.69 0.76 0.87 0.34 0.5 ]
# best Node: [0.51 0.49 0.41 0.53 0.5  0.58 0.97 0.71 0.87 0.5 ]
# best Node: [0.64 0.47 0.16 0.54 0.92 0.63 0.82 0.25 0.41 0.28]
# best Node: [0.54 0.41 0.56 0.54 0.01 0.7  0.59 0.61 0.27 0.95]
# best Node: [0.88 0.05 0.76 0.37 0.19 0.43 0.12 0.27 0.41 0.59]
# best Node: [0.5 0.9]
# best Node: [0.96 0.49]
# best Node: [0.74 0.76]
# best Node: [0.6  0.54]
# best Node: [0.73 0.57]
# best Node: [0.5  0.95 0.27]
# best Node: [0.21 0.83 0.93]
# best Node: [0.25 0.78 0.8 ]
# best Node: [0.39 0.9  0.78]
# best Node: [0.52 0.89 0.01 0.56 0.02]
# best Node: [0.91 0.49 0.02 0.5  0.87]
# best Node: [0.98 0.45 0.47 0.74 0.36]
# best Node: [0.57 0.07 0.98 0.49 0.54]
# best Node: [0.61 0.25 0.93 0.05 0.49]
# best Node: [0.52 0.89 0.39 0.14 0.   0.36 0.96]
# best Node: [0.13 0.5  0.42 0.38 0.71 0.9  0.63]
# best Node: [0.03 0.57 0.54 0.25 0.1  0.38 0.79]
# best Node: [0.1  0.95 0.9  0.09 0.44 0.63 0.79]
# best Node: [0.34 0.59 0.43 0.52 0.52 0.02 0.34]
# best Node: [0.66 0.54 0.73 0.26 0.55 0.28 0.73]
# best Node: [0.5  0.61 0.44 0.54 0.38 0.02 0.82 0.93 0.76]
# best Node: [0.19 0.51 0.07 0.79 0.75 0.19 0.72 0.4  0.48]
# best Node: [0.15 0.07 0.39 0.57 0.81 0.5  0.7  0.86 0.68]
# best Node: [0.5  0.84 0.28 0.26 0.59 0.97 0.49 0.4  0.45 0.02]
# best Node: [0.88 0.6  0.47 0.85 0.06 0.05 0.33 0.35 0.41 0.31]
# best Node: [0.72 0.97 0.73 0.43 0.6  0.28 0.79 0.54 0.18 0.55]
# best Node: [0.6  0.55 0.91 0.06 0.47 0.5  0.87 0.72 0.84 0.89]
# best Node: [0.71 0.67 0.19 0.1  0.12 0.48 0.98 0.85 0.47 0.67]
# best Node: [0.5 0.4]
# best Node: [0.24 0.21]
# best Node: [0.36 0.21]
# best Node: [0.29 0.16]
# best Node: [0.51 0.85 0.45]
# best Node: [0.11 0.64 0.53]
# best Node: [0.27 0.98 0.87]
# best Node: [0.36 0.84 0.81]
# best Node: [0.23 0.84 0.74]
# best Node: [0.5  0.36 0.73 0.42 0.44]
# best Node: [0.78 0.46 0.02 0.31 0.48]
# best Node: [0.52 0.33 0.55 0.82 0.89 0.7  0.61]
# best Node: [0.71 0.53 0.52 0.08 0.71 0.19 0.43]
# best Node: [0.7  0.39 0.07 0.54 0.97 0.76 0.53]
# best Node: [0.8  0.25 0.46 0.22 0.38 0.57 0.85]
# best Node: [0.45 0.15 0.16 0.49 0.97 0.64 0.54]
# best Node: [0.52 0.55 0.4  0.85 0.34 0.01 0.95 0.23 0.86]
# best Node: [0.96 0.51 0.68 0.71 0.17 0.28 0.92 0.19 0.94]
# best Node: [0.55 0.3  0.63 0.5  0.14 0.19 0.6  0.21 0.72]
# best Node: [0.54 0.26 0.85 0.19 0.56 0.69 0.98 0.18 0.03]
# best Node: [0.52 0.69 0.14 0.14 0.02 0.3  0.13 0.08 0.82 0.27]
# best Node: [0.29 0.5  0.02 0.87 0.8  0.79 0.61 0.73 0.44 0.25]
# best Node: [0.46 0.56 0.5  0.82 0.62 0.06 0.43 0.54 0.29 0.81]
# best Node: [0.49 0.72]
# best Node: [0.73 0.51]
# best Node: [0.77 0.82]
# best Node: [0.97 0.76]
# best Node: [0.94 0.88]
# best Node: [0.48 0.99 0.44]
# best Node: [0.51 0.98 0.7  0.76 0.92]
# best Node: [0.44 0.53 0.78 0.85 0.11]
# best Node: [0.52 0.98 0.   0.36 0.57 0.11 0.28]
# best Node: [0.85 0.5  0.89 0.8  0.46 0.09 0.64]
# best Node: [0.82 0.11 0.49 0.82 0.48 0.88 0.11]
# best Node: [0.9  0.45 0.28 0.49 0.99 0.56 0.6 ]
# best Node: [0.8  0.47 0.41 0.08 0.21 0.48 0.13]
# best Node: [0.75 0.24 0.2  0.32 0.8  0.59 0.35]
# best Node: [0.65 0.33 0.99 0.14 0.48 0.7  0.76]
# best Node: [0.84 0.51 0.22 0.46 0.84 0.9  0.79]
# best Node: [0.37 0.55 0.37 0.45 0.28 0.54 0.55]
# best Node: [0.5  0.61 0.05 0.33 0.19 0.65 0.78 0.17 0.61]
# best Node: [0.39 0.52 0.44 0.41 0.25 0.83 0.37 0.53 0.83]
# best Node: [0.04 0.64 1.   0.59 0.19 0.67 0.31 0.38 0.9 ]
# best Node: [0.26 0.85 0.45 0.69 0.55 0.76 0.67 0.61 0.55]
# best Node: [0.46 0.49 0.77 0.15 0.44 0.4  0.42 0.39 0.36 0.15]
# best Node: [0.31 0.33 0.43 0.81 0.4  0.72 0.08 0.79 0.17 0.11]
# best Node: [0.2  0.41 0.71 0.11 0.57 0.52 0.42 0.66 0.68 0.31]
# best Node: [0.5  0.52 0.46 0.26 0.71 0.97 0.28 1.   0.14 0.35]
# best Node: [0.49 0.41]
# best Node: [0.69 0.47]
# best Node: [0.75 0.98]
# best Node: [0.75 0.9 ]
# best Node: [0.49 0.92 0.37]
# best Node: [0.46 0.52 0.07]
# best Node: [0.15 0.04 0.49]
# best Node: [0.24 0.31 0.57]
# best Node: [0.24 0.27 0.94]
# best Node: [0.5  0.49 0.12 0.78 0.79]
# best Node: [0.47 0.53 0.88 0.9  0.24]
# best Node: [0.36 0.56 0.22 0.51 0.43]
# best Node: [0.49 0.22 0.02 0.03 0.42 0.72 0.91]
# best Node: [0.98 0.71 0.46 0.35 0.77 0.09 0.16]
# best Node: [0.55 0.86 0.29 0.53 0.37 0.56 0.5 ]
# best Node: [0.89 0.67 0.54 0.29 0.5  0.54 0.31]
# best Node: [0.99 0.24 0.05 0.56 0.   0.5  0.05]
# best Node: [0.49 0.37 0.39 0.51 0.15 0.46 0.86 0.65 0.69]
# best Node: [0.29 0.39 0.19 0.53 0.01 0.43 0.45 0.68 0.97]
# best Node: [0.15 0.72 0.25 0.47 0.29 0.86 0.73 0.75 0.65]
# best Node: [0.5  0.29 0.37 0.37 0.38 0.64 0.65 0.92 0.53 0.59]
# best Node: [0.26 0.91 0.54 0.14 0.46 0.79 0.2  0.38 0.14 0.57]
# best Node: [0.18 0.78 0.79 0.97 0.65 0.45 0.28 0.82 0.63 0.37]
# best Node: [0.04 0.96 0.27 0.4  0.94 0.48 0.05 0.93 0.13 0.28]
# best Node: [0.49 0.87]
# best Node: [0.24 0.77]
# best Node: [0.11 0.87]
# best Node: [0.12 0.9 ]
# best Node: [0.19 0.96]
# best Node: [0.51 0.13 0.49]
# best Node: [0.06 0.47 0.63]
# best Node: [0.17 0.29 0.5 ]
# best Node: [0.49 0.82 0.99 0.65 0.56]
# best Node: [0.92 0.52 0.23 0.61 0.7 ]
# best Node: [0.73 0.21 0.51 0.48 0.88]
# best Node: [0.59 0.22 0.15 0.47 0.56]
# best Node: [0.73 0.13 0.5  0.12 0.94]
# best Node: [0.83 0.36 0.11 0.3  0.95]
# best Node: [0.43 0.27 0.11 0.17 0.78]
# best Node: [0.51 0.28 0.16 0.02 0.01 0.49 0.61]
# best Node: [0.12 0.49 0.01 0.07 0.63 0.6  0.38]
# best Node: [0.19 0.36 0.49 0.86 0.09 0.09 0.58]
# best Node: [0.38 0.17 0.32 0.52 0.76 0.53 0.33]
# best Node: [0.39 0.41 0.18 0.84 0.49 0.39 0.89]
# best Node: [0.32 0.48 0.23 0.89 0.67 0.59 0.47]
# best Node: [0.52 0.94 0.7  0.36 0.51 0.2  0.82 0.57 0.04]
# best Node: [0.04 0.49 0.49 0.66 0.35 0.55 0.59 0.6  0.8 ]
# best Node: [0.41 0.08 0.66 0.85 0.49 0.99 0.32 0.32 0.68]
# best Node: [0.39 0.29 0.97 0.82 0.13 0.4  0.07 0.06 0.6 ]
# best Node: [0.5  0.31 0.79 0.62 0.6  0.25 0.01 0.68 0.56 0.97]
# best Node: [0.27 0.59 0.52 0.26 0.14 0.04 0.03 0.82 0.33 0.61]
# best Node: [0.49 0.41]
# best Node: [0.37 0.5 ]
# best Node: [0.44 0.77]
# best Node: [0.44 0.64]
# best Node: [0.51 0.31 0.36]
# best Node: [0.19 0.52 0.51]
# best Node: [0.09 0.7  0.52]
# best Node: [0.08 0.8  0.7 ]
# best Node: [0.15 0.72 0.52]
# best Node: [0.49 0.62 0.54 0.64 0.64]
# best Node: [0.7  0.72 0.52 0.35 0.65]
# best Node: [0.71 0.96 0.74 0.06 0.59]
# best Node: [0.6  0.75 0.55 0.38 0.03]
# best Node: [0.44 0.84 0.5  0.28 0.26]
# best Node: [0.46 0.8  0.87 0.22 0.08]
# best Node: [0.49 0.32 0.76 0.63 0.4  0.76 0.62]
# best Node: [0.83 0.51 0.17 0.28 0.66 0.54 0.14]
# best Node: [0.87 0.14 0.5  0.16 0.56 0.05 0.42]
# best Node: [0.89 0.45 0.29 0.32 0.59 0.07 0.4 ]
# best Node: [0.74 0.41 0.76 0.19 0.62 0.05 0.6 ]
# best Node: [0.48 0.52 0.33 0.56 0.27 0.74 0.97 0.09 0.31]
# best Node: [0.46 0.52 0.45 0.01 0.84 0.32 0.51 0.65 0.11]
# best Node: [0.24 0.37 0.53 0.6  0.26 0.66 0.64 0.9  0.17]
# best Node: [0.28 0.5  0.79 0.43 0.67 0.1  0.43 0.56 0.19]
# best Node: [0.2  0.02 0.69 0.26 0.59 0.48 0.03 0.7  0.25]
# best Node: [0.49 0.6  0.21 0.44 0.56 0.32 0.76 0.11 0.69 0.1 ]
# best Node: [0.06 0.5  0.28 0.07 0.54 0.7  0.59 0.32 0.62 0.62]
# best Node: [0.19 0.93 0.52 0.15 0.19 0.39 0.46 0.57 0.47 0.45]
# best Node: [0.31 0.83 0.62 0.63 0.13 0.2  0.36 0.33 0.   0.85]
# best Node: [0.52 0.18]
# best Node: [0.24 0.24]
# best Node: [0.4  0.21]
# best Node: [0.37 0.06]
# best Node: [0.32 0.18]
# best Node: [0.32 0.1 ]
# best Node: [0.51 0.07 0.26]
# best Node: [0.36 0.49 0.16]
# best Node: [0.29 0.4  0.27]
# best Node: [0.16 0.46 0.29]
# best Node: [0.5  0.99 0.55 0.87 0.32]
# best Node: [0.11 0.55 0.53 0.69 0.56]
# best Node: [0.1  0.88 0.76 0.54 0.95]
# best Node: [0.43 0.98 0.97 0.24 0.51]
# best Node: [0.37 0.73 0.98 0.3  0.71]
# best Node: [0.48 0.46 0.12 0.33 0.14 0.61 0.81]
# best Node: [0.36 0.67 0.48 0.03 0.38 0.78 0.34]
# best Node: [0.04 0.78 0.72 0.08 0.24 0.21 0.52]
# best Node: [0.24 0.68 0.49 0.78 0.21 0.5  0.35]
# best Node: [0.29 0.97 0.33 0.04 0.26 0.48 0.36]
# best Node: [0.51 0.58 0.65 0.31 0.45 0.23 0.84 0.22 0.73]
# best Node: [0.61 0.8  0.5  0.94 0.61 0.44 0.79 0.49 0.96]
# best Node: [0.69 0.56 0.42 0.67 0.77 0.11 0.67 0.81 1.  ]
# best Node: [0.4  0.22 0.69 0.52 0.42 0.58 0.85 0.8  0.97]
# best Node: [0.51 0.52 0.25 0.11 0.45 0.65 0.03 0.28 0.95 0.71]
# best Node: [0.82 0.52 0.28 0.53 0.53 0.03 0.84 0.61 0.66 0.97]
# best Node: [0.52 0.24 0.5  0.27 0.56 0.95 0.61 0.6  0.33 0.8 ]
# best Node: [0.66 0.14 0.24 0.32 0.99 0.77 0.62 0.6  0.64 0.85]
# best Node: [0.78 0.09 0.3  0.52 0.86 0.97 0.42 0.19 0.19 0.07]
# best Node: [0.37 0.25 0.33 0.45 0.98 0.62 0.43 0.57 0.37 0.36]
# best Node: [0.5 0.9]
# best Node: [0.75 0.63]
# best Node: [0.7  0.77]
# best Node: [0.71 0.78]
# best Node: [0.5  0.42 0.11]
# best Node: [0.37 0.53 0.28]
# best Node: [0.14 0.28 0.53]
# best Node: [0.23 0.5  0.57]
# best Node: [0.03 0.27 0.96]
# best Node: [0.23 0.39 0.77]
# best Node: [0.11 0.43 0.85]
# best Node: [0.49 0.55 0.17 0.18 0.98]
# best Node: [0.34 0.5  0.09 0.13 0.52]
# best Node: [0.2  0.02 0.48 0.73 0.07]
# best Node: [0.28 0.5  0.27 0.99 0.19]
# best Node: [0.5  0.5  0.11 0.58 0.62 0.24 0.04]
# best Node: [0.27 0.5  0.48 0.61 0.12 0.81 0.79]
# best Node: [0.5  0.6  0.24 0.03 0.23 0.48 0.17 0.75 0.25]
# best Node: [0.35 0.5  0.2  0.47 0.21 0.26 0.92 0.56 0.22]
# best Node: [0.22 0.45 0.46 0.54 0.49 0.41 0.71 0.93 0.88]
# best Node: [0.2  0.36 0.26 0.97 0.72 0.48 0.71 0.61 0.8 ]
# best Node: [0.06 0.03 0.27 0.31 0.74 0.74 0.54 0.93 0.13]
# best Node: [0.5  0.36 0.49 0.37 0.32 0.25 0.06 0.73 0.61 0.85]
# best Node: [0.25 0.61 0.5  0.63 0.54 0.39 0.93 0.51 0.37 0.04]
# best Node: [0.42 0.5  0.55 0.49 0.32 0.81 0.76 0.45 0.9  0.53]
# best Node: [0.51 0.88 0.91 0.59 0.7  0.63 0.56 0.34 0.81 0.41]
# best Node: [0.5  0.62]
# best Node: [0.5  0.61]
# best Node: [0.51 0.51]
# best Node: [0.5  0.4  0.84]
# best Node: [0.23 0.52 0.84]
# best Node: [0.02 0.56 0.5 ]
# best Node: [0.25 0.74 0.23]
# best Node: [0.24 0.77 0.34]
# best Node: [0.5  0.78 0.52 0.02 0.81]
# best Node: [0.29 0.24 0.49 0.19 0.37]
# best Node: [0.37 0.35 0.22 0.45 0.67]
# best Node: [0.44 0.2  0.13 0.9  0.07]
# best Node: [0.24 0.08 0.12 0.18 0.13]
# best Node: [0.42 0.34 0.33 0.17 0.35]
# best Node: [0.2  0.24 0.24 0.3  0.35]
# best Node: [0.68 0.49 0.01 0.25 0.23]
# best Node: [0.53 0.33 0.25 0.3  0.53 0.83 0.2 ]
# best Node: [0.49 0.9  0.11 0.82 0.52 0.47 0.84]
# best Node: [0.29 0.61 0.07 0.26 0.34 0.42 0.57]
# best Node: [0.52 0.86 0.35 0.82 0.03 0.54 0.44 0.33 1.  ]
# best Node: [0.24 0.51 0.88 0.57 0.48 0.53 0.72 0.95 0.42]
# best Node: [0.37 0.13 0.99 0.58 0.82 0.38 0.49 0.43 0.02]
# best Node: [0.37 0.52 0.36 0.9  0.87 0.37 0.38 0.29 0.07]
# best Node: [0.5  0.66 0.72 0.05 0.38 0.71 0.56 0.74 0.98 0.26]
# best Node: [0.33 0.52 0.65 0.71 0.78 0.66 0.61 0.68 0.13 0.02]
# best Node: [0.11 0.27 0.85 0.43 0.1  0.92 0.42 0.23 0.64 0.96]
# best Node: [0.11 0.4  0.53 0.48 0.02 0.41 0.41 0.51 0.41 0.03]
# best Node: [0.2  0.33 0.54 0.13 0.73 0.52 0.09 0.49 0.25 0.29]
# best Node: [0.22 0.53 0.7  0.46 0.64 0.92 0.42 0.42 0.45 0.51]
# best Node: [0.49 0.41]
# best Node: [0.68 0.47]
# best Node: [0.75 0.63]
# best Node: [0.87 0.71]
# best Node: [0.93 0.72]
# best Node: [0.49 0.07 0.85]
# best Node: [0.71 0.51 0.59]
# best Node: [0.58 0.32 0.52]
# best Node: [0.73 0.07 0.36]
# best Node: [0.92 0.26 0.21]
# best Node: [0.85 0.1  0.21]
# best Node: [0.85 0.15 0.19]
# best Node: [0.49 0.51 0.22 0.47 1.  ]
# best Node: [0.43 0.92 0.48 0.24 0.74]
# best Node: [0.52 0.13 0.99 0.65 0.84 0.57 0.9 ]
# best Node: [0.49 0.5  0.15 0.18 0.17 0.25 0.34]
# best Node: [0.06 0.22 0.14 0.26 0.44 0.69 0.82]
# best Node: [0.37 0.04 0.16 0.29 0.73 0.13 0.33]
# best Node: [0.71 0.37 0.39 0.03 0.52 0.37 0.62]
# best Node: [0.49 0.04 1.   0.69 0.71 0.3  0.02 0.73 0.44]
# best Node: [0.47 0.97 0.53 0.7  0.14 0.06 0.37 0.7  0.79]
# best Node: [0.19 0.86 0.56 0.56 0.49 0.15 0.44 0.23 0.54]
# best Node: [0.01 0.72 0.95 0.57 0.96 0.48 0.64 0.5  0.47]
# best Node: [0.49 0.88 0.49 0.68 0.98 0.03 0.9  0.9  0.85 0.56]
# best Node: [0.35 0.5  0.46 0.49 0.26 0.43 0.38 0.78 0.2  0.62]
# best Node: [0.37 0.02 0.74 0.62 0.43 0.12 0.41 0.1  0.28 0.78]
# best Node: [0.41 0.23 0.87 0.36 0.38 0.43 0.13 0.43 0.9  0.35]
# best Node: [0.34 0.53 0.38 0.78 0.01 0.52 0.18 0.35 0.25 0.18]
# best Node: [0.67 0.18 0.8  0.38 0.18 0.56 0.46 0.36 0.73 0.15]
# best Node: [0.59 0.55 0.69 0.54 0.15 0.27 0.58 0.35 0.67 0.16]
# best Node: [0.5  0.72]
# best Node: [0.94 0.46]
# best Node: [0.74 0.36]
# best Node: [0.67 0.22]
# best Node: [0.63 0.15]
# best Node: [0.6 0.1]
# best Node: [0.57 0.08]
# best Node: [0.5 0.7 0.3]
# best Node: [0.11 0.5  0.16]
# best Node: [0.28 0.45 0.52]
# best Node: [0.21 0.06 0.25]
# best Node: [0.14 0.29 0.21]
# best Node: [0.18 0.11 0.28]
# best Node: [0.13 0.24 0.48]
# best Node: [0.52 0.72 0.06 0.57 0.32]
# best Node: [0.39 0.51 0.5  0.04 0.39]
# best Node: [0.24 0.44 0.53 0.13 0.88]
# best Node: [0.02 0.45 0.63 0.56 0.92]
# best Node: [0.03 0.27 0.49 0.27 0.78]
# best Node: [0.51 0.4  0.9  0.11 0.31 0.75 0.92]
# best Node: [0.63 0.45 0.48 0.85 0.86 0.59 0.61]
# best Node: [0.9  0.12 0.51 0.84 0.95 0.5  0.49]
# best Node: [0.5  0.69 0.66 0.38 0.99 0.75 0.39 0.78 0.87]
# best Node: [0.63 0.62 0.26 0.69 0.89 0.69 0.67 0.06 0.79]
# best Node: [0.79 0.6  0.48 0.77 0.79 0.79 0.4  0.46 0.95]
# best Node: [0.84 0.69 0.25 0.12 0.86 0.76 0.5  0.56 0.66]
# best Node: [0.5  0.26 0.25 0.26 0.74 0.49 0.09 0.03 0.37 0.27]
# best Node: [0.88 0.49 0.7  0.49 0.73 0.27 0.31 0.84 0.95 0.52]
# best Node: [0.86 0.03 0.88 0.52 0.16 0.84 0.54 0.65 0.92 0.51]
# best Node: [0.72 0.27 0.94 0.92 0.57 0.61 0.19 0.12 0.99 0.42]
# best Node: [0.77 0.08 0.85 0.63 0.67 0.89 0.47 0.69 0.52 0.74]
# best Node: [0.52 0.66]
# best Node: [0.29 0.49]
# best Node: [0.25 0.11]
# best Node: [0.2  0.13]
# best Node: [0.19 0.28]
# best Node: [0.51 0.83 0.89]
# best Node: [0.67 0.48 0.73]
# best Node: [0.51 0.61 0.48]
# best Node: [0.76 0.98 0.25]
# best Node: [0.5  0.85 0.29 0.79 0.93]
# best Node: [0.69 0.47 0.58 0.89 0.64]
# best Node: [1.   0.42 0.5  0.87 0.65]
# best Node: [0.6  0.41 0.02 0.48 0.29]
# best Node: [0.79 0.19 0.23 0.26 0.21]
# best Node: [0.49 0.7  0.16 0.65 0.76 0.06 0.19]
# best Node: [0.18 0.5  0.92 0.24 0.17 0.2  0.36]
# best Node: [0.43 0.61 0.46 0.19 0.06 0.79 0.68]
# best Node: [0.13 0.53 0.02 0.44 0.39 0.5  0.15]
# best Node: [0.33 0.93 0.23 0.55 0.37 0.81 0.31]
# best Node: [0.49 0.24 0.09 0.22 0.36 0.64 0.35 0.93 0.14]
# best Node: [0.93 0.49 0.39 0.03 0.33 0.3  0.76 0.05 0.53]
# best Node: [0.52 0.9  0.52 0.55 0.75 0.73 0.44 0.09 0.69]
# best Node: [0.51 0.85 0.95 0.51 0.61 0.61 0.47 0.86 0.32]
# best Node: [0.51 0.49 0.9  0.63 0.98 0.52 0.34 0.86 0.38]
# best Node: [0.54 0.55 0.93 0.39 0.91 0.42 0.33 0.55 0.26]
# best Node: [0.5  0.1  0.2  0.18 0.24 0.47 0.54 0.77 0.41 0.21]
# best Node: [0.65 0.21 0.7  0.49 0.24 0.42 0.66 0.76 0.3  0.66]
# best Node: [0.49 0.32]
# best Node: [0.18 0.54]
# best Node: [0.02 0.77]
# best Node: [0.13 0.62]
# best Node: [0.03 0.62]
# best Node: [0.49 0.5  0.15]
# best Node: [0.41 0.5  0.7 ]
# best Node: [0.31 0.41 0.48]
# best Node: [0.13 0.38 0.64]
# best Node: [0.51 0.98 0.87 0.31 0.1 ]
# best Node: [0.26 0.37 0.52 0.36 0.29]
# best Node: [0.28 0.19 0.62 0.84 0.3 ]
# best Node: [0.53 0.3  0.37 0.56 0.78 0.32 0.96]
# best Node: [0.27 0.46 0.05 0.82 0.77 0.88 0.54]
# best Node: [0.51 0.6  0.61 0.9  0.53 0.5  0.87 0.39 0.59]
# best Node: [0.82 0.77 0.67 0.78 0.26 0.5  0.97 0.26 0.65]
# best Node: [0.68 0.62 0.75 0.82 0.35 0.   0.51 0.16 0.27]
# best Node: [0.39 0.74 0.64 0.89 0.26 0.56 0.4  0.18 0.8 ]
# best Node: [0.34 0.86 0.81 0.54 0.19 0.21 0.43 0.11 0.91]
# best Node: [0.5  0.44 0.91 0.34 0.76 0.49 0.88 0.9  0.51 0.31]
# best Node: [0.83 0.49 0.89 0.24 0.14 0.12 0.52 0.58 0.48 0.62]
# best Node: [0.52 0.55 0.86 0.68 0.08 0.31 0.53 0.47 0.4  0.64]
# best Node: [0.97 0.93 0.77 0.45 0.14 0.13 0.41 0.84 0.86 0.96]
# best Node: [0.49 0.75 0.72 0.89 0.34 0.16 0.57 0.76 0.75 0.86]
# best Node: [0.48 0.43]
# best Node: [0.51 0.51]
# best Node: [0.75 0.99]
# best Node: [0.79 0.76]
# best Node: [0.87 0.9 ]
# best Node: [0.49 0.75 0.17]
# best Node: [0.4  0.69 0.48]
# best Node: [0.25 0.81 0.93]
# best Node: [0.51 0.18 0.34 0.6  0.08]
# best Node: [0.88 0.51 0.06 0.54 0.93]
# best Node: [0.81 0.73 0.06 0.65 0.49]
# best Node: [0.94 0.85 0.14 0.75 0.7 ]
# best Node: [0.5  0.2  0.72 0.13 0.08 0.3  0.41]
# best Node: [0.27 0.5  0.5  0.07 0.36 0.29 0.34]
# best Node: [0.49 0.51 0.4  0.79 0.51 0.18 0.16 0.4  0.  ]
# best Node: [0.71 0.5  0.19 0.68 1.   0.11 0.51 0.99 0.35]
# best Node: [0.69 0.49 0.36 0.54 0.53 0.03 0.74 0.59 0.39]
# best Node: [0.5  0.6  0.35 0.94 0.37 0.3  0.04 0.26 0.66 0.97]
# best Node: [0.43 0.5  0.01 0.57 0.85 0.51 0.31 0.24 0.45 0.33]
# best Node: [0.28 0.41 0.49 0.07 0.97 0.62 0.29 0.66 0.75 0.46]
# best Node: [0.23 0.49 0.98 0.91 0.99 0.42 0.22 0.91 0.53 0.39]
# best Node: [0.24 0.21 0.59 0.87 0.68 0.69 0.48 0.72 0.91 0.89]
# best Node: [0.01 0.43 0.71 0.56 0.95 0.02 0.41 0.26 0.42 0.89]
# best Node: [0.18 0.03 0.47 0.89 0.97 0.51 0.57 0.49 0.06 0.29]
# best Node: [0.2  0.54 0.69 0.77 0.77 0.53 0.79 0.24 0.1  0.9 ]
# best Node: [0.52 0.58 0.53 0.81 0.89 0.67 0.49 0.54 0.38 0.84]
# best Node: [0.5  0.56]
# best Node: [0.87 0.5 ]
# best Node: [0.74 0.36]
# best Node: [0.8  0.35]
# best Node: [0.51 0.04 0.41]
# best Node: [0.52 0.51 0.2 ]
# best Node: [0.74 0.07 0.52]
# best Node: [0.9  0.33 0.31]
# best Node: [0.86 0.28 0.31]
# best Node: [0.63 0.29 0.43]
# best Node: [0.9  0.37 0.52]
# best Node: [0.5  0.36 0.83 0.29 0.47]
# best Node: [0.71 0.71 0.49 0.95 0.98]
# best Node: [0.98 0.81 0.18 0.95 0.91]
# best Node: [0.5  0.44 0.49 0.82 0.68 0.32 0.37]
# best Node: [0.31 0.21 0.5  0.23 0.13 0.92 0.88]
# best Node: [0.41 0.22 0.8  0.31 0.67 0.45 0.78]
# best Node: [0.49 0.48 0.35 0.28 0.11 0.71 0.49 0.28 0.98]
# best Node: [0.12 0.46 0.51 0.63 0.29 0.35 0.4  0.56 0.81]
# best Node: [0.28 0.4  0.51 0.9  0.85 0.72 0.64 0.71 0.4 ]
# best Node: [0.06 0.63 0.67 0.57 0.68 0.94 0.43 0.15 0.41]
# best Node: [0.5  0.42 0.29 0.9  0.71 0.37 0.91 0.33 0.96 0.46]
# best Node: [0.47 0.5  0.75 0.48 0.31 0.34 0.51 0.72 0.86 0.38]
# best Node: [0.03 0.55 0.65 0.39 0.1  0.73 0.41 0.5  0.44 0.61]
# best Node: [0.51 0.98]
# best Node: [0.3 0.5]
# best Node: [0.24 0.61]
# best Node: [0.25 0.73]
# best Node: [0.33 0.61]
# best Node: [0.3  0.71]
# best Node: [0.48 0.28 0.85]
# best Node: [0.9  0.34 0.5 ]
# best Node: [0.74 0.38 0.9 ]
# best Node: [0.89 0.23 0.72]
# best Node: [0.49 0.78 0.43 0.23 0.35]
# best Node: [0.16 0.65 0.11 0.47 0.76]
# best Node: [0.33 0.54 0.29 0.62 0.43]
# best Node: [0.34 0.75 0.28 0.81 0.52]
# best Node: [0.49 0.64 0.39 0.4  0.46 0.17 0.81]
# best Node: [0.49 0.5  0.23 0.38 0.44 0.83 0.79]
# best Node: [0.24 0.28 0.56 0.7  0.42 0.6  0.55]
# best Node: [0.33 0.43 0.17 0.51 0.02 0.77 0.16]
# best Node: [0.42 0.55 0.33 0.36 0.29 0.5  0.51]
# best Node: [0.58 0.27 0.35 0.54 0.05 0.32 0.5 ]
# best Node: [0.5  0.04 0.18 0.64 0.12 0.58 0.5  0.92 0.43]
# best Node: [0.09 0.14 0.55 0.4  0.96 0.13 0.2  0.5  0.33]
# best Node: [0.51 0.29 0.69 0.64 0.5  0.53 0.59 0.61 0.64 0.92]
# best Node: [0.07 0.64 0.51 0.52 0.92 0.17 0.24 0.84 0.63 0.18]
# best Node: [0.32 0.54 0.77 0.54 0.83 0.72 0.78 0.64 0.11 0.19]
# best Node: [0.51 0.85 0.53 0.58 0.58 0.22 0.53 0.55 0.6  0.02]
# best Node: [0.34 0.81 0.88 0.65 0.13 0.52 0.5  0.92 0.4  0.37]
# best Node: [0.49 0.97]
# best Node: [0.16 0.51]
# best Node: [0.36 0.26]
# best Node: [0.39 0.33]
# best Node: [0.35 0.37]
# best Node: [0.5  0.64 0.12]
# best Node: [0.95 0.51 0.61]
# best Node: [0.65 0.18 0.52]
# best Node: [0.79 0.32 0.82]
# best Node: [0.73 0.4  0.91]
# best Node: [0.51 1.   0.88 0.28 0.52]
# best Node: [0.68 0.38 0.48 0.71 0.75]
# best Node: [0.88 0.31 0.57 0.95 0.51]
# best Node: [0.7  0.2  0.88 0.89 0.29]
# best Node: [0.52 0.07 0.65 0.65 0.02]
# best Node: [0.48 0.56 0.44 0.54 0.04 0.03 0.73]
# best Node: [0.9  0.97 0.5  0.24 0.09 0.24 0.47]
# best Node: [0.85 0.87 0.23 0.49 0.02 0.84 0.72]
# best Node: [0.65 0.88 0.11 0.34 0.19 0.79 0.98]
# best Node: [0.5  0.68 0.23 0.17 0.55 0.42 0.08 0.24 0.71]
# best Node: [0.49 0.52 0.94 0.13 0.43 0.35 0.92 0.91 0.35]
# best Node: [0.22 0.8  0.5  0.47 0.7  0.31 0.18 0.46 0.32]
# best Node: [0.05 0.92 0.83 0.91 0.5  0.68 0.35 1.   0.77]
# best Node: [0.02 0.63 0.91 0.96 0.48 0.85 0.33 0.66 0.27]
# best Node: [0.27 0.7  0.57 0.64 0.11 0.69 0.78 0.42 0.6 ]
# best Node: [0.39 0.6  0.8  0.6  0.86 0.54 0.57 0.79 0.43]
# best Node: [0.4  0.67 0.6  0.49 0.4  0.87 0.66 0.35 0.24]
# best Node: [0.48 0.86 0.82 0.3  0.3  0.93 0.63 0.69 0.57]
# best Node: [0.5  0.25 0.01 0.75 0.07 0.4  0.92 0.6  0.99 0.76]
# best Node: [0.48 0.49 0.09 0.9  0.01 0.61 0.98 0.89 1.   0.69]
# best Node: [0.32 0.71 0.52 0.74 0.03 0.37 0.72 0.83 0.51 0.57]
# best Node: [0.51 0.25]
# best Node: [0.38 0.51]
# best Node: [0.24 0.25]
# best Node: [0.11 0.27]
# best Node: [0.12 0.36]
# best Node: [0.06 0.31]
# best Node: [0.5  0.11 0.26]
# best Node: [0.66 0.52 0.39]
# best Node: [0.76 0.67 0.45]
# best Node: [0.95 0.82 0.75]
# best Node: [0.87 0.78 0.59]
# best Node: [0.95 0.91 0.66]
# best Node: [0.8  0.87 0.49]
# best Node: [0.49 0.32 0.65 0.36 0.91]
# best Node: [0.11 0.26 0.46 0.29 0.56]
# best Node: [0.12 0.32 0.22 0.51 0.79]
# best Node: [0.07 0.38 0.2  0.77 0.5 ]
# best Node: [0.03 0.27 0.17 0.78 0.64]
# best Node: [0.09 0.23 0.23 0.8  0.75]
# best Node: [0.51 0.4  0.22 0.54 0.57 0.44 0.08]
# best Node: [0.4  0.98 0.5  0.95 0.08 0.18 0.17]
# best Node: [0.23 0.96 0.79 0.53 0.46 0.95 0.35]
# best Node: [0.46 0.67 0.55 0.64 0.43 0.35 0.34]
# best Node: [0.25 0.83 0.57 0.75 0.58 0.42 0.34]
# best Node: [0.27 0.9  0.89 0.89 0.94 0.23 0.54]
# best Node: [0.25 0.5  0.64 0.98 0.69 0.34 0.79]
# best Node: [0.42 0.61 0.99 0.32 0.53 0.12 0.85]
# best Node: [0.5  0.85 0.   0.44 0.14 0.71 0.94 0.45 0.38]
# best Node: [0.88 0.97 0.27 0.48 0.49 0.71 0.76 0.12 0.26]
# best Node: [0.73 0.79 0.26 0.31 0.74 0.65 0.45 0.97 0.41]
# best Node: [0.51 0.81 0.33 0.1  0.54 0.79 0.8  0.51 0.93]
# best Node: [0.86 0.82 0.22 0.37 0.35 0.85 0.54 0.69 0.48]
# best Node: [0.5  0.18 0.95 0.47 0.76 0.78 0.02 0.41 0.92 0.28]
# best Node: [0.08 0.51 0.45 0.67 0.64 0.86 0.3  0.54 0.36 0.26]
# best Node: [0.28 0.49 0.27 0.32 0.54 0.26 0.38 0.56 0.21 0.49]
# best Node: [0.26 0.33 0.31 0.17 0.23 0.57 0.96 0.04 0.23 0.14]
# best Node: [0.19 0.16 0.34 0.07 0.47 0.71 0.77 0.47 0.5  0.5 ]
# best Node: [0.35 0.07 0.69 0.23 0.31 0.51 0.67 0.95 0.16 0.64]
# best Node: [0.5  0.87]
# best Node: [0.3 0.5]
# best Node: [0.25 0.42]
# best Node: [0.5  0.29 0.58]
# best Node: [0.61 0.35 0.4 ]
# best Node: [0.51 0.37 0.4 ]
# best Node: [0.5  0.48 0.36 0.38 0.04]
# best Node: [0.75 0.19 0.5  0.61 0.3 ]
# best Node: [0.95 0.18 0.12 0.91 0.07]
# best Node: [0.93 0.4  0.18 0.51 0.4 ]
# best Node: [0.85 0.18 0.32 0.64 0.25]
# best Node: [0.96 0.29 0.36 0.37 0.14]
# best Node: [0.51 0.5  0.95 0.76 0.69 0.2  0.17]
# best Node: [0.44 0.5  0.33 0.32 0.62 0.56 0.88]
# best Node: [0.22 0.91 0.48 0.02 0.04 0.27 0.3 ]
# best Node: [0.13 0.94 0.32 0.49 0.4  0.03 0.23]
# best Node: [0.18 0.58 0.18 0.14 0.02 0.22 0.43]
# best Node: [0.49 0.93 0.8  0.45 0.01 0.44 0.7  0.09 0.78]
# best Node: [0.39 0.51 0.74 0.49 0.79 0.18 0.03 0.57 0.84]
# best Node: [0.38 0.62 0.9  0.23 0.44 0.43 0.11 0.19 0.54]
# best Node: [0.52 0.97 0.5  0.07 0.64 0.41 0.44 0.5  0.56]
# best Node: [0.5  0.04 0.84 0.41 0.32 0.19 0.08 0.06 0.35 0.36]
# best Node: [0.25 0.08 0.33 0.42 0.46 0.21 0.6  0.7  0.8  0.44]
# best Node: [0.18 0.11 0.09 0.02 0.13 0.48 0.43 0.23 0.71 0.91]
# best Node: [0.17 0.1  0.24 0.44 0.39 0.69 0.33 0.67 0.44 0.68]
# best Node: [0.5  0.13]
# best Node: [0.33 0.48]
# best Node: [0.2  0.75]
# best Node: [0.13 0.55]
# best Node: [0.09 0.67]
# best Node: [0.14 0.67]
# best Node: [0.51 0.71 0.13]
# best Node: [0.7  0.49 0.36]
# best Node: [0.77 0.26 0.06]
# best Node: [0.9  0.07 0.08]
# best Node: [0.84 0.13 0.2 ]
# best Node: [0.49 0.23 0.5  0.89 0.06]
# best Node: [0.5  0.49 0.41 0.6  0.79]
# best Node: [0.68 0.64 0.5  0.54 0.9 ]
# best Node: [0.84 0.74 0.87 0.48 0.97]
# best Node: [0.96 0.84 0.76 0.79 0.48]
# best Node: [0.5  0.19 0.46 0.34 0.36 0.55 0.43]
# best Node: [0.32 0.52 0.77 0.18 0.67 0.84 0.55]
# best Node: [0.24 0.49 0.79 0.24 0.87 0.88 0.61]
# best Node: [0.49 0.91 0.12 0.74 0.14 0.12 0.13 0.92 0.97]
# best Node: [0.63 0.49 0.43 0.83 0.64 0.3  0.99 0.93 0.62]
# best Node: [0.66 0.26 0.5  0.39 0.41 0.76 0.74 0.52 0.61]
# best Node: [0.78 0.35 0.53 0.38 0.6  0.01 0.83 0.56 0.26]
# best Node: [0.67 0.24 0.63 0.34 0.58 0.22 0.33 0.43 0.59]
# best Node: [0.56 0.42 0.51 0.33 0.64 0.64 0.5  0.61 0.23]
# best Node: [0.86 0.08 0.67 0.51 0.64 0.79 0.31 0.6  0.33]
# best Node: [0.93 0.35 0.83 0.55 0.7  0.34 0.48 0.52 0.27]
# best Node: [0.49 0.79 0.4  0.5  0.77 0.45 0.85 0.25 0.08 0.23]
# best Node: [0.35 0.48 0.18 0.51 0.01 0.19 0.05 0.1  0.28 0.11]
# best Node: [0.47 0.29 0.24 0.98 0.55 0.02 0.26 0.48 0.61 0.66]
# best Node: [0.43 0.16 0.35 0.85 0.6  0.2  0.1  0.55 0.04 0.04]
# best Node: [0.52 0.19]
# best Node: [0.14 0.51]
# best Node: [0.26 0.85]
# best Node: [0.29 0.77]
# best Node: [0.33 0.71]
# best Node: [0.3  0.71]
# best Node: [0.5  0.32 0.17]
# best Node: [0.42 0.51 0.71]
# best Node: [0.26 0.34 0.52]
# best Node: [0.14 0.25 0.63]
# best Node: [0.51 0.59 0.7  0.23 0.9 ]
# best Node: [0.59 0.41 0.76 0.05 0.48]
# best Node: [0.73 0.37 0.71 0.22 0.68]
# best Node: [0.7  0.28 0.95 0.36 0.54]
# best Node: [0.63 0.23 0.81 0.1  0.69]
# best Node: [0.85 0.25 0.74 0.31 0.87]
# best Node: [0.5  0.55 0.85 0.68 0.92 0.97 0.53]
# best Node: [0.13 0.5  0.98 0.76 0.65 0.72 0.33]
# best Node: [0.03 0.17 0.5  0.18 0.19 0.56 0.59]
# best Node: [0.35 0.04 0.03 0.02 0.57 0.26 0.38]
# best Node: [0.47 0.42 0.25 0.01 0.37 0.49 0.35]
# best Node: [0.36 0.41 0.26 0.1  0.34 0.57 0.44]
# best Node: [0.5  0.82 0.25 0.77 0.85 0.5  0.41 0.15 0.58]
# best Node: [0.23 0.49 0.18 0.5  0.12 0.08 0.58 0.24 0.87]
# best Node: [0.45 0.18 0.05 0.61 0.32 0.2  0.89 0.57 0.19]
# best Node: [0.41 0.27 0.17 0.64 0.61 0.44 0.49 0.66 0.46]
# best Node: [0.41 0.26 0.46 0.68 0.51 0.4  0.94 0.46 0.41]
# best Node: [0.21 0.2  0.48 0.37 0.39 0.26 0.58 0.38 0.31]
# best Node: [0.51 0.63 0.3  0.28 0.57 0.24 0.94 0.79 0.18 0.21]
# best Node: [0.93 0.5  0.49 0.64 0.11 0.93 0.77 0.91 0.99 0.64]
# best Node: [0.52 0.96 0.51 0.63 0.34 0.86 0.35 0.37 0.43 0.77]
# best Node: [0.57 0.52 0.68 0.48 0.5  0.31 0.23 0.72 0.91 0.94]
# best Node: [0.5  0.18]
# best Node: [0.63 0.49]
# best Node: [0.85 0.24]
# best Node: [0.86 0.34]
# best Node: [0.93 0.36]
# best Node: [0.94 0.38]
# best Node: [0.97 0.4 ]
# best Node: [0.49 0.3  0.08]
# best Node: [0.24 0.45 0.04]
# best Node: [0.16 0.23 0.17]
# best Node: [0.15 0.18 0.05]
# best Node: [0.5  0.22 0.86 0.07 0.64]
# best Node: [0.36 0.5  0.72 0.15 0.74]
# best Node: [0.17 0.46 0.52 0.81 0.44]
# best Node: [0.24 0.46 0.59 0.76 0.49]
# best Node: [0.25 0.49 0.98 0.52 0.93]
# best Node: [0.31 0.29 0.89 0.7  0.8 ]
# best Node: [0.5  0.5  0.32 0.37 0.47 0.47 0.33]
# best Node: [0.96 0.33 0.17 0.3  0.49 0.51 0.36]
# best Node: [0.62 0.13 0.02 0.04 0.17 0.9  0.62]
# best Node: [0.77 0.36 0.17 0.32 0.36 0.79 0.36]
# best Node: [0.52 0.18 0.87 0.71 0.46 0.39 0.29 0.77 0.52]
# best Node: [0.15 0.52 0.83 0.26 0.3  0.17 0.57 0.88 0.12]
# best Node: [0.42 0.5  0.14 0.32 0.5  0.19 0.39 0.35 0.28]
# best Node: [0.29 0.33 0.48 0.06 0.14 0.39 0.22 0.55 0.68]
# best Node: [0.04 0.19 0.3  0.27 0.24 0.26 0.08 0.62 0.24]
# best Node: [0.5  0.21 0.74 0.93 0.2  0.52 0.83 0.38 0.33 0.44]
# best Node: [0.68 0.58 0.48 0.19 0.34 0.38 0.7  0.73 0.44 0.73]
# best Node: [0.92 0.75 0.89 0.41 0.48 0.32 0.77 0.5  0.31 0.25]
# best Node: [0.5  0.35]
# best Node: [0.25 0.5 ]
# best Node: [0.37 0.57]
# best Node: [0.32 0.57]
# best Node: [0.49 0.61 0.87]
# best Node: [0.48 0.31 0.52]
# best Node: [0.27 0.4  0.59]
# best Node: [0.22 0.25 0.73]
# best Node: [0.13 0.1  0.87]
# best Node: [0.16 0.12 0.98]
# best Node: [0.34 0.12 0.9 ]
# best Node: [0.49 0.23 0.01 0.73 0.75]
# best Node: [0.35 0.5  0.35 0.59 0.95]
# best Node: [0.31 0.95 0.47 0.43 0.76]
# best Node: [0.04 0.76 0.68 0.48 0.05]
# best Node: [0.42 0.6  0.97 1.   0.53]
# best Node: [0.47 0.73 0.81 0.84 0.29]
# best Node: [0.5  0.68 0.24 0.45 0.65 0.02 0.17]
# best Node: [0.12 0.65 0.49 0.14 0.19 0.17 0.4 ]
# best Node: [0.19 0.86 0.33 0.5  0.39 0.97 0.65]
# best Node: [0.17 0.89 0.13 0.33 0.47 0.7  0.06]
# best Node: [0.5  0.03 0.49 0.27 0.72 0.28 0.29 0.71 0.07]
# best Node: [0.85 0.03 0.51 0.4  0.87 0.53 0.18 0.39 0.44]
# best Node: [0.54 0.12 0.36 0.02 0.54 0.68 0.54 0.47 0.39]
# best Node: [0.96 0.23 0.22 0.38 0.25 0.99 0.14 0.54 0.46]
# best Node: [0.66 0.15 0.68 0.07 0.78 0.66 0.3  0.42 0.34]
# best Node: [0.89 0.6  0.49 0.14 0.51 0.45 0.48 0.68 0.21]
# best Node: [0.49 0.56 0.28 0.73 0.54 0.17 0.91 0.7  0.18 0.12]
# best Node: [0.18 0.21 0.47 0.57 0.62 0.99 0.36 0.22 0.83 0.44]
# best Node: [0.18 0.25 0.59 0.51 0.33 0.27 0.35 0.18 0.73 0.83]
# best Node: [0.23 0.29 0.8  0.79 0.12 0.54 0.74 0.94 0.16 0.91]
# best Node: [0.07 0.   0.63 0.89 0.62 0.47 0.46 0.56 0.66 0.78]
# best Node: [0.51 0.01]
# best Node: [0.97 0.49]
# best Node: [0.75 0.3 ]
# best Node: [0.95 0.24]
# best Node: [0.93 0.24]
# best Node: [0.5  0.1  0.04]
# best Node: [0.38 0.5  0.59]
# best Node: [0.19 0.27 0.53]
# best Node: [0.09 0.24 0.72]
# best Node: [0.5  0.77 0.31 0.13 0.03]
# best Node: [0.01 0.51 0.25 0.3  0.18]
# best Node: [0.3  0.22 0.5  0.41 0.91]
# best Node: [0.18 0.5  0.55 0.46 0.29]
# best Node: [0.07 0.12 0.72 0.18 0.48]
# best Node: [0.02 0.19 0.86 0.41 0.41]
# best Node: [0.5  0.03 0.81 0.36 0.61 0.75 0.2 ]
# best Node: [0.46 0.51 0.05 0.39 0.33 0.01 0.2 ]
# best Node: [0.17 0.07 0.49 0.29 0.44 0.27 0.81]
# best Node: [0.22 0.2  0.1  0.22 0.69 0.4  0.55]
# best Node: [0.5  0.93 0.61 0.73 0.05 0.44 0.01 0.56 0.11]
# best Node: [0.1  0.48 0.7  0.47 0.16 0.81 0.29 0.2  0.42]
# best Node: [0.28 0.27 0.83 0.19 0.24 0.85 0.56 0.26 0.97]
# best Node: [0.1  0.23 0.88 0.19 0.13 0.67 0.83 0.46 0.08]
# best Node: [0.5  0.74 0.89 0.06 0.09 0.96 0.43 0.03 0.47]
# best Node: [0.76 0.18 0.91 0.02 0.33 0.61 0.87 0.28 0.22]
# best Node: [0.49 0.43 0.42 0.03 0.94 0.99 0.87 0.12 0.77 0.57]
# best Node: [0.69 0.49 0.39 0.22 0.4  0.42 0.81 1.   0.87 0.2 ]
# best Node: [0.84 0.13 0.49 0.65 0.72 0.16 0.33 0.58 0.55 0.65]
# best Node: [0.69 0.14 0.63 0.65 0.51 0.3  0.37 0.9  0.82 0.44]
# best Node: [0.99 0.28 0.62 0.59 0.28 0.48 0.49 0.61 0.39 0.61]
# best Node: [1.   0.15 0.88 0.82 0.11 0.44 0.17 0.64 0.18 0.51]
# best Node: [0.84 0.38 0.62 0.99 0.62 0.78 0.52 0.59 0.42 0.16]
# best Node: [0.68 0.62 0.75 0.66 0.08 0.5  0.53 0.5  0.42 0.32]
# best Node: [0.5  0.35]
# best Node: [0.75 0.13]
# best Node: [0.85 0.12]
# best Node: [0.82 0.09]
# best Node: [0.8  0.07]
# best Node: [0.5  0.38 0.01]
# best Node: [0.26 0.27 0.21]
# best Node: [0.33 0.42 0.27]
# best Node: [0.38 0.27 0.03]
# best Node: [0.27 0.39 0.21]
# best Node: [0.41 0.37 0.2 ]
# best Node: [0.23 0.39 0.13]
# best Node: [0.5  0.77 0.31 0.54 0.84]
# best Node: [0.51 0.5  0.15 0.97 0.89]
# best Node: [0.88 0.42 0.49 0.11 0.83]
# best Node: [0.55 0.17 0.19 0.48 0.44]
# best Node: [0.89 0.29 0.13 1.   0.44]
# best Node: [0.76 0.06 0.03 0.77 0.66]
# best Node: [0.93 0.23 0.14 0.57 0.74]
# best Node: [0.5  0.83 0.89 0.07 0.69 0.74 0.07]
# best Node: [0.75 0.31 0.34 0.05 0.45 0.29 0.31]
# best Node: [0.7  0.35 0.38 0.39 0.73 0.5  0.04]
# best Node: [0.74 0.08 0.35 0.02 0.95 0.89 0.4 ]
# best Node: [0.49 0.25 0.75 0.58 0.75 0.28 0.88 0.85 0.56]
# best Node: [0.94 0.   0.76 0.77 0.51 0.49 0.69 0.48 0.79]
# best Node: [0.97 0.38 0.64 0.72 0.29 0.39 0.51 0.66 0.39]
# best Node: [0.49 0.66 0.24 0.87 0.93 0.08 0.98 0.75 0.81 0.99]
# best Node: [0.77 0.48 0.84 0.01 0.03 0.01 0.29 0.18 0.95 0.65]
# best Node: [0.57 0.06 0.47 0.23 0.95 0.66 0.36 0.54 0.27 0.07]
# best Node: [0.7  0.4  0.29 0.44 0.75 0.9  0.37 0.18 0.32 0.17]
# best Node: [0.96 0.35 0.34 0.67 0.55 0.49 0.41 0.77 0.71 0.66]
# best Node: [0.67 0.07 0.15 0.62 0.95 0.48 0.07 0.54 0.8  0.34]
# best Node: [0.5  0.94]
# best Node: [0.26 0.75]
# best Node: [0.32 0.86]
# best Node: [0.33 0.83]
# best Node: [0.29 0.8 ]
# best Node: [0.51 0.24 0.68]
# best Node: [0.12 0.8  0.49]
# best Node: [0.27 0.52 0.5 ]
# best Node: [0.28 0.77 0.62]
# best Node: [0.29 0.76 0.73]
# best Node: [0.39 0.75 0.75]
# best Node: [0.49 0.47 0.16 0.94 0.94]
# best Node: [0.96 0.51 0.93 0.55 0.95]
# best Node: [0.7  0.95 0.61 0.48 0.83]
# best Node: [0.97 0.88 0.51 0.81 0.49]
# best Node: [0.73 0.63 0.94 0.7  0.65]
# best Node: [0.69 0.78 0.73 0.86 0.74]
# best Node: [0.91 0.72 0.84 0.79 0.49]
# best Node: [0.5  0.34 0.58 0.1  0.68 0.44 0.46]
# best Node: [0.19 0.52 0.55 0.34 0.01 0.21 0.84]
# best Node: [0.45 0.6  0.5  0.37 0.1  0.04 0.17]
# best Node: [0.39 1.   0.57 0.52 0.14 0.35 0.07]
# best Node: [0.29 0.67 0.8  0.96 0.03 0.49 0.24]
# best Node: [0.28 0.73 0.8  0.54 0.27 0.74 0.5 ]
# best Node: [0.31 0.99 0.57 0.77 0.11 0.92 0.14]
# best Node: [0.51 0.84 0.09 0.19 0.31 0.48 0.76 0.45 0.76]
# best Node: [0.88 0.51 0.37 0.1  0.28 0.35 0.84 0.57 0.52]
# best Node: [0.78 0.72 0.5  0.02 0.4  0.48 0.48 0.87 0.79]
# best Node: [0.58 0.66 0.59 0.61 0.55 0.33 0.26 0.68 0.66]
# best Node: [0.88 0.94 0.51 0.71 0.26 0.44 0.56 0.52 0.85]
# best Node: [0.9  0.83 0.98 0.35 0.02 0.01 0.36 0.6  0.96]
# best Node: [0.49 0.04 0.15 0.75 0.23 0.62 0.59 0.13 0.06 0.89]
# best Node: [0.67 0.27 0.5  0.37 0.32 0.48 0.15 0.82 0.05 0.71]
# best Node: [0.69 0.24 0.98 0.46 0.55 0.18 0.3  0.54 0.85 0.56]
# best Node: [0.56 0.37 0.71 0.43 0.01 0.45 0.78 0.03 0.48 0.58]
# best Node: [0.49 0.4 ]
# best Node: [0.49 0.41]
# best Node: [0.51 0.46]
# best Node: [0.51 0.51 0.45]
# best Node: [0.3  0.45 0.5 ]
# best Node: [0.44 0.24 0.91]
# best Node: [0.34 0.46 0.78]
# best Node: [0.35 0.36 0.7 ]
# best Node: [0.49 0.34 0.58]
# best Node: [0.51 0.71 0.07 0.25 0.02]
# best Node: [0.16 0.83 0.4  0.51 0.27]
# best Node: [0.01 0.84 0.33 0.14 0.52]
# best Node: [0.22 0.75 0.25 0.04 0.48]
# best Node: [0.5  0.03 0.92 0.04 0.89 0.91 0.5 ]
# best Node: [0.69 0.26 0.71 0.5  0.97 0.84 0.18]
# best Node: [0.78 0.37 0.99 0.31 0.58 0.7  0.2 ]
# best Node: [0.51 0.09 0.8  0.18 0.23 0.98 0.7  0.25 0.04]
# best Node: [0.66 0.4  0.5  0.38 0.18 0.43 0.37 0.42 0.87]
# best Node: [0.52 0.49 0.43 0.48 0.37 0.99 0.   0.66 0.48]
# best Node: [0.79 0.11 0.34 0.48 0.57 0.93 0.56 0.89 0.27]
# best Node: [0.95 0.38 0.04 0.85 0.36 0.46 0.05 0.63 0.46]
# best Node: [1.   0.25 0.17 0.92 0.45 0.7  0.5  0.55 0.46]
# best Node: [0.48 0.1  0.92 0.45 0.44 0.71 0.75 0.56 0.44 0.88]
# best Node: [0.96 0.51 1.   0.67 0.39 0.43 0.78 0.08 0.9  0.38]
# best Node: [0.62 0.55 0.48 0.9  0.18 0.23 0.55 0.26 0.14 0.77]
# best Node: [0.76 0.57 0.88 0.69 0.07 0.41 0.42 0.66 0.34 0.58]
# best Node: [0.93 0.83 0.71 0.88 0.28 0.23 0.54 0.79 0.51 0.18]
# best Node: [0.69 0.61 0.88 0.59 0.3  0.35 0.75 0.5  0.18 0.28]
# best Node: [0.5 0.8]
# best Node: [0.28 0.5 ]
# best Node: [0.26 0.2 ]
# best Node: [0.13 0.03]
# best Node: [0.2  0.06]
# best Node: [0.51 0.25 0.38]
# best Node: [0.37 0.35 0.51]
# best Node: [0.24 0.14 0.43]
# best Node: [0.17 0.28 0.32]
# best Node: [0.06 0.35 0.25]
# best Node: [0.12 0.35 0.27]
# best Node: [0.5  0.12 0.2  0.25 0.61]
# best Node: [0.54 0.5  0.79 0.56 0.6 ]
# best Node: [0.78 0.89 0.48 0.51 0.68]
# best Node: [0.97 0.76 0.01 0.67 0.82]
# best Node: [0.7  0.76 0.26 0.53 0.93]
# best Node: [0.51 0.12 0.3  0.1  0.19 0.81 0.92]
# best Node: [0.72 0.31 0.51 0.48 0.91 0.73 0.49]
# best Node: [0.83 0.39 0.44 0.03 0.81 0.64 0.33]
# best Node: [0.5  0.03 0.65 0.74 0.1  0.25 0.73 0.68 0.12]
# best Node: [0.95 0.97 0.76 0.51 0.48 0.44 0.31 0.9  0.13]
# best Node: [0.96 0.65 0.76 0.06 0.89 0.6  0.16 0.6  0.17]
# best Node: [0.93 0.79 0.88 0.32 0.76 0.51 0.9  0.6  0.3 ]
# best Node: [0.74 0.58 0.84 0.2  0.95 0.66 0.89 0.53 0.44]
# best Node: [0.5  0.26 0.82 0.31 0.07 0.86 0.09 0.79 0.78 0.69]
# best Node: [0.5  0.5  0.36 0.44 0.21 0.25 0.37 0.95 0.23 0.61]
# best Node: [0.18 0.1  0.49 0.83 0.83 0.61 0.51 0.55 0.15 0.42]
# best Node: [0.07 0.36 0.85 0.93 0.46 0.61 0.32 0.32 0.73 0.65]
# best Node: [0.47 0.46 0.77 0.59 0.54 0.33 0.87 0.52 0.46 0.49]
# best Node: [0.75 0.25 0.63 0.95 0.58 0.4  0.59 0.58 0.66 0.98]
# best Node: [0.59 0.39 0.42 0.69 0.4  0.49 0.56 0.98 0.55 0.77]
# best Node: [0.51 0.97]
# best Node: [0.57 0.5 ]
# best Node: [0.76 0.22]
# best Node: [0.79 0.22]
# best Node: [0.88 0.18]
# best Node: [0.9 0.1]
# best Node: [0.94 0.09]
# best Node: [0.88 0.06]
# best Node: [0.97 0.05]
# best Node: [0.5  0.82 0.09]
# best Node: [0.5  0.49 0.39]
# best Node: [0.25 0.62 0.51]
# best Node: [0.25 0.92 0.88]
# best Node: [0.36 0.92 0.91]
# best Node: [0.51 0.37 0.79 0.09 0.36]
# best Node: [0.18 0.5  0.68 0.45 0.88]
# best Node: [0.08 0.59 0.8  0.24 0.72]
# best Node: [0.5  0.02 0.36 0.81 0.09 0.19 0.42]
# best Node: [0.84 0.51 0.49 0.34 0.12 0.37 0.81]
# best Node: [0.92 0.25 0.98 0.54 0.58 0.91 0.23]
# best Node: [0.51 0.22 0.03 0.04 1.   0.35 0.13 0.69 0.36]
# best Node: [0.2  0.5  0.7  0.57 0.13 0.57 0.69 0.21 0.08]
# best Node: [0.42 0.94 0.51 0.5  0.64 0.41 0.54 0.77 0.91]
# best Node: [0.5  0.87 0.78 0.43 0.52 0.76 0.89 0.44 0.15]
# best Node: [0.23 0.54 0.92 0.26 0.93 0.53 0.76 0.77 0.67]
# best Node: [0.35 0.62 0.55 0.29 0.73 0.81 0.72 0.38 0.86]
# best Node: [0.5  0.54 0.89 0.45 0.96 0.48 0.18 0.79 0.06 0.34]
# best Node: [0.21 0.5  0.13 0.04 0.18 0.62 0.43 0.57 0.84 0.51]
# best Node: [0.08 0.16 0.5  0.43 0.05 0.85 0.72 0.06 0.56 0.58]
# best Node: [0.4  0.34 0.14 0.48 0.7  0.47 0.43 0.17 0.95 0.68]
# best Node: [0.19 0.37 0.2  0.71 0.58 0.92 0.64 0.42 0.69 0.46]
# best Node: [0.45 0.2  0.53 0.21 0.45 0.54 0.78 0.66 0.89 0.61]
# best Node: [0.82 0.22 0.11 0.41 0.5  0.52 0.96 0.31 0.66 0.75]
# best Node: [0.5 0.2]
# best Node: [0.03 0.51]
# best Node: [0.24 0.64]
# best Node: [0.24 0.76]
# best Node: [0.19 0.82]
# best Node: [0.18 0.81]
# best Node: [0.49 0.91 0.46]
# best Node: [0.82 0.49 0.57]
# best Node: [0.74 0.21 0.9 ]
# best Node: [0.96 0.25 0.55]
# best Node: [0.85 0.25 0.78]
# best Node: [0.86 0.2  0.72]
# best Node: [0.84 0.12 0.7 ]
# best Node: [0.49 0.24 0.9  0.67 0.02]
# best Node: [0.3  0.25 0.05 0.91 0.49]
# best Node: [0.23 0.28 0.33 0.81 0.4 ]
# best Node: [0.63 0.18 0.24 0.9  0.39]
# best Node: [0.5  0.9  0.33 0.97 0.03 0.68 0.68]
# best Node: [0.35 0.93 0.47 0.03 0.5  0.36 0.35]
# best Node: [0.23 0.53 0.29 0.48 0.5  0.3  0.62]
# best Node: [0.28 0.83 0.09 0.25 0.32 0.63 0.69]
# best Node: [0.13 0.2  0.38 0.07 0.16 0.56 0.87]
# best Node: [0.31 0.46 0.42 0.03 0.46 0.53 0.85]
# best Node: [0.49 0.32 0.43 0.63 0.83 0.64 0.27 0.79 0.9 ]
# best Node: [0.44 0.52 0.47 0.85 0.43 0.81 0.9  0.02 0.69]
# best Node: [0.44 0.63 0.66 0.5  0.62 0.04 0.1  0.75 0.59]
# best Node: [0.1  0.69 0.6  0.18 0.51 0.16 0.73 0.84 0.15]
# best Node: [0.02 0.66 0.85 0.09 0.62 0.5  0.94 0.49 0.09]
# best Node: [0.42 0.7  0.55 0.09 0.79 0.12 0.5  0.88 0.33]
# best Node: [0.33 0.73 0.98 0.06 0.65 0.11 0.6  0.49 0.15]
# best Node: [0.35 0.8  0.63 0.38 0.98 0.71 0.73 0.43 0.59]
# best Node: [0.17 0.27 0.97 0.53 0.58 0.24 0.82 0.36 0.85]
# best Node: [0.51 0.86 0.48 0.01 0.51 0.17 0.91 0.66 0.67]
# best Node: [0.58 0.49 0.9  0.3  0.54 0.37 0.67 0.75 0.66]
# best Node: [0.51 0.05 0.98 0.19 0.13 0.14 0.19 0.44 0.13 0.33]
# best Node: [0.55 0.49 0.51 0.56 0.83 0.86 0.5  0.66 0.58 0.63]
# best Node: [0.79 0.19 0.53 0.23 0.47 0.28 0.23 0.53 0.51 0.91]
# best Node: [0.57 0.23 0.81 0.52 0.77 0.3  0.31 0.99 0.96 0.65]
# best Node: [0.97 0.21 0.65 0.72 0.46 0.3  0.74 0.23 0.95 0.26]
# best Node: [0.98 0.19 0.94 0.67 0.54 0.54 0.97 0.23 0.14 0.74]
# best Node: [0.95 0.33 0.79 0.67 0.85 0.33 0.41 0.51 0.54 0.63]
# best Node: [0.5 0.6]
# best Node: [0.24 0.94]
# best Node: [0.37 0.84]
# best Node: [0.48 0.89]
# best Node: [0.45 0.93]
# best Node: [0.43 0.93]
# best Node: [0.5  0.33 0.99]
# best Node: [0.71 0.51 0.73]
# best Node: [0.6  0.62 0.76]
# best Node: [0.56 0.62 0.8 ]
# best Node: [0.48 0.2  0.42 0.82 0.13]
# best Node: [0.14 0.52 0.5  0.89 0.01]
# best Node: [0.38 0.91 0.5  0.54 0.56]
# best Node: [0.23 0.97 0.68 0.62 0.44]
# best Node: [0.38 0.88 0.78 0.65 0.29]
# best Node: [0.34 0.97 0.29 0.76 0.4 ]
# best Node: [0.46 0.78 0.44 0.88 0.5 ]
# best Node: [0.5  0.06 0.92 1.   0.85 0.06 0.09]
# best Node: [0.34 0.36 0.54 0.7  0.82 0.51 0.26]
# best Node: [0.24 0.41 0.18 0.85 0.81 0.12 0.52]
# best Node: [0.16 0.3  0.48 0.89 0.76 0.18 0.62]
# best Node: [0.5  0.38 0.21 0.33 0.69 0.29 0.96 0.07 0.44]
# best Node: [0.58 0.06 0.36 0.11 0.44 0.86 0.51 0.34 0.31]
# best Node: [0.58 0.38 0.33 0.38 0.31 0.71 0.63 0.14 0.37]
# best Node: [0.45 0.03 0.76 0.19 0.3  0.65 0.51 0.44 0.59]
# best Node: [0.47 0.51 0.44 0.22 0.52 0.41 0.71 0.17 0.63]
# best Node: [0.5  0.58 0.24 0.73 0.86 0.19 0.63 0.89 0.34 0.37]
# best Node: [0.7  0.5  0.7  0.1  0.29 0.4  0.68 0.22 0.18 0.23]
# best Node: [0.56 0.64 0.48 0.9  0.2  0.05 0.5  0.52 0.76 0.58]
# best Node: [0.87 0.93 0.66 0.04 0.45 0.16 0.38 0.51 0.65 0.61]
# best Node: [0.5  0.94]
# best Node: [0.86 0.5 ]
# best Node: [0.95 0.62]
# best Node: [0.94 0.54]
# best Node: [0.94 0.55]
# best Node: [0.87 0.6 ]
# best Node: [0.5  0.38 0.88]
# best Node: [0.95 0.52 0.46]
# best Node: [0.73 0.25 0.64]
# best Node: [0.89 0.4  0.69]
# best Node: [0.75 0.39 0.68]
# best Node: [0.5  0.95 0.27 0.48 0.55]
# best Node: [0.98 0.69 0.08 0.52 0.15]
# best Node: [0.76 0.55 0.15 0.1  0.19]
# best Node: [0.85 0.74 0.1  0.25 0.02]
# best Node: [0.49 0.31 0.66 0.63 0.79 0.8  0.25]
# best Node: [0.25 0.51 0.61 0.21 0.82 0.33 0.26]
# best Node: [0.08 0.31 0.5  0.39 0.25 0.28 0.9 ]
# best Node: [0.28 0.04 0.07 0.55 0.49 0.52 0.5 ]
# best Node: [0.07 0.25 0.06 0.73 0.28 0.5  0.36]
# best Node: [0.11 0.3  0.05 0.68 0.01 0.01 0.46]
# best Node: [0.26 0.38 0.25 0.68 0.04 0.39 0.1 ]
# best Node: [0.5  0.13 0.34 0.67 0.2  0.22 0.93 0.49 0.63]
# best Node: [0.18 0.14 0.09 0.53 0.34 0.56 0.87 0.79 0.54]
# best Node: [0.5  0.82 0.65 0.48 0.44 0.75 0.94 0.49 0.44 0.86]
# best Node: [0.52 0.62 0.77 0.86 0.03 0.56 0.55 0.96 0.48 0.4 ]
# best Node: [0.77 0.75 0.51 0.99 0.09 0.82 0.82 0.58 0.59 0.75]
# best Node: [0.5  0.72]
# best Node: [0.32 0.28]
# best Node: [0.38 0.3 ]
# best Node: [0.41 0.39]
# best Node: [0.44 0.43]
# best Node: [0.4  0.46]
# best Node: [0.5  0.02 0.08]
# best Node: [0.27 0.49 0.86]
# best Node: [0.24 0.17 0.52]
# best Node: [0.26 0.35 0.66]
# best Node: [0.35 0.25 0.78]
# best Node: [0.38 0.16 0.77]
# best Node: [0.49 0.94 0.58 0.51 0.2 ]
# best Node: [0.08 0.49 0.46 0.31 0.64]
# best Node: [0.38 0.15 0.12 0.52 0.68]
# best Node: [0.33 0.27 0.29 0.84 0.52]
# best Node: [0.07 0.22 0.19 0.87 0.19]
# best Node: [0.38 0.26 0.07 0.9  0.13]
# best Node: [0.51 0.46 0.39 0.74 0.16 0.04 0.01]
# best Node: [0.37 0.5  0.22 0.49 0.46 0.07 0.55]
# best Node: [0.33 0.79 0.5  0.6  0.22 0.77 0.53]
# best Node: [0.51 0.94 0.66 0.51 0.19 0.89 0.84]
# best Node: [0.25 0.83 0.79 0.05 0.49 0.65 0.41]
# best Node: [0.03 0.74 0.65 0.35 0.87 0.57 0.48]
# best Node: [0.22 0.69 0.92 0.37 0.65 0.55 0.58]
# best Node: [0.5  0.84 0.66 0.15 0.13 0.78 0.58 0.04 0.89]
# best Node: [0.05 0.04 0.76 0.19 0.19 0.75 0.55 0.93 0.81]
# best Node: [0.28 0.41 0.78 0.06 0.74 0.44 0.76 0.55 0.73]
# best Node: [0.51 0.11 0.55 0.34 0.44 0.6  0.38 0.51 0.28 0.5 ]
# best Node: [0.9  0.06 0.6  0.86 0.82 0.49 0.87 0.87 0.07 0.97]
# best Node: [0.97 0.5  0.78 0.96 0.26 0.51 0.93 0.62 0.27 0.55]
# best Node: [0.68 0.35 0.91 0.34 0.55 0.38 0.69 0.53 0.29 0.84]
# best Node: [0.88 0.67 0.61 0.45 0.7  0.53 0.49 0.83 0.33 0.77]
# best Node: [0.42 0.43 0.92 0.62 0.71 0.61 0.51 0.8  0.49 0.77]
# best Node: [0.5 0.8]
# best Node: [0.95 0.51]
# best Node: [0.9  0.78]
# best Node: [0.87 0.66]
# best Node: [0.97 0.66]
# best Node: [0.5  0.97 0.26]
# best Node: [0.64 0.6  0.51]
# best Node: [0.74 0.88 0.15]
# best Node: [0.84 0.76 0.19]
# best Node: [0.51 0.94 0.63 0.81 0.86]
# best Node: [0.62 0.5  0.72 0.41 0.13]
# best Node: [0.77 0.21 0.73 0.75 0.05]
# best Node: [0.8  0.38 0.7  0.82 0.33]
# best Node: [0.74 0.25 0.69 0.71 0.23]
# best Node: [0.51 0.33 0.78 0.13 0.03 0.77 0.9 ]
# best Node: [0.05 0.51 0.35 0.22 0.58 0.87 0.21]
# best Node: [0.41 0.42 0.52 0.88 0.27 0.31 0.44]
# best Node: [0.47 0.5  0.07 0.25 0.57 0.35 0.43]
# best Node: [0.28 0.47 0.08 0.3  0.41 0.02 0.64]
# best Node: [0.5  0.75 0.24 0.05 0.72 0.98 0.93 0.66 0.74]
# best Node: [0.57 0.91 0.52 0.58 0.78 0.54 0.53 0.09 0.67]
# best Node: [0.95 0.52 0.39 0.49 0.85 0.49 0.19 0.16 0.33]
# best Node: [0.57 0.57 0.43 0.34 0.5  0.51 0.38 0.86 0.2 ]
# best Node: [0.58 0.71 0.2  0.17 0.49 0.05 0.52 0.79 0.07]
# best Node: [0.95 0.71 0.32 0.15 0.34 0.03 0.31 0.5  0.21]
# best Node: [0.51 0.04 0.74 0.89 0.32 0.95 0.91 0.47 0.04 0.58]
# best Node: [0.26 0.49 0.36 0.26 0.3  0.43 0.3  0.44 0.73 0.72]
# best Node: [0.44 0.83 0.2  0.31 0.51 0.07 0.66 0.68 0.14 0.86]
# best Node: [0.07 0.57 0.29 0.35 0.86 0.27 0.36 0.41 0.73 0.41]
# best Node: [0.25 0.8  0.41 0.28 0.68 0.23 0.78 0.38 0.24 0.13]
# best Node: [0.5  0.37]
# best Node: [0.38 0.15]
# best Node: [0.43 0.23]
# best Node: [0.49 0.45 0.8 ]
# best Node: [0.45 0.52 0.61]
# best Node: [0.38 0.51 0.64]
# best Node: [0.34 0.4  0.47]
# best Node: [0.5  0.8  0.12 0.29 0.96]
# best Node: [0.03 0.5  0.09 0.37 0.5 ]
# best Node: [0.19 0.08 0.48 0.25 0.66]
# best Node: [0.11 0.35 0.67 0.49 0.52]
# best Node: [0.19 0.44 0.97 0.64 0.46]
# best Node: [0.24 0.14 0.84 0.85 0.82]
# best Node: [0.38 0.23 0.56 0.59 0.69]
# best Node: [0.43 0.44 0.71 0.7  0.62]
# best Node: [0.43 0.19 0.66 0.93 0.55]
# best Node: [0.48 0.92 0.74 0.55 0.71 0.84 0.15]
# best Node: [0.72 0.74 0.35 0.47 0.45 0.37 0.85]
# best Node: [0.95 0.81 0.13 0.13 0.92 0.45 0.64]
# best Node: [0.74 0.61 0.45 0.08 0.57 0.4  0.38]
# best Node: [0.24 0.64 0.04 0.06 0.83 0.17 0.11]
# best Node: [0.5  0.1  0.24 0.8  0.42 0.52 0.89 0.49 0.1 ]
# best Node: [0.23 0.7  0.54 0.24 0.27 0.39 0.75 0.42 0.01]
# best Node: [0.26 0.77 0.17 0.26 0.43 0.59 0.16 0.54 0.65]
# best Node: [0.33 0.91 0.09 0.43 0.39 0.44 0.09 0.35 0.42]
# best Node: [0.21 0.57 0.74 0.2  0.58 0.54 0.29 0.43 0.42]
# best Node: [0.27 0.42 0.16 0.32 0.46 0.79 0.48 0.43 0.61]
# best Node: [0.34 0.47 0.57 0.24 0.52 0.8  0.2  0.22 0.01]
# best Node: [0.51 0.51 0.66 0.86 0.35 0.95 0.83 0.85 0.75 0.95]
# best Node: [0.47 0.08 0.51 0.65 0.22 0.69 0.67 0.08 0.81 0.97]
# best Node: [0.17 0.25 0.04 1.   0.09 0.56 0.1  0.68 0.39 0.2 ]
# best Node: [0.1  0.25 0.31 0.61 0.08 0.93 0.48 0.48 0.76 0.44]
# best Node: [0.49 0.01]
# best Node: [0.04 0.51]
# best Node: [0.24 0.93]
# best Node: [0.23 0.76]
# best Node: [0.17 0.83]
# best Node: [0.5  0.37 0.53]
# best Node: [0.27 0.05 0.87]
# best Node: [0.49 0.25 0.77]
# best Node: [0.41 0.24 0.78]
# best Node: [0.5  0.14 0.69]
# best Node: [0.5  0.3  0.78 0.43 0.88]
# best Node: [0.57 0.49 0.06 0.75 0.22]
# best Node: [0.62 0.74 0.23 0.53 0.59]
# best Node: [0.64 0.79 0.51 0.61 0.5 ]
# best Node: [0.9  0.56 0.31 0.8  0.52]
# best Node: [0.49 0.19 0.71 0.58 0.08 0.86 0.56]
# best Node: [0.32 0.52 0.03 0.34 0.72 0.36 0.39]
# best Node: [0.25 0.11 0.46 0.49 0.74 0.32 0.07]
# best Node: [0.5  0.7  0.67 0.46 0.94 0.24 0.18 0.27 0.81]
# best Node: [0.88 0.5  0.17 0.54 0.58 0.43 0.32 0.98 0.66]
# best Node: [0.76 0.08 0.51 0.87 0.52 0.66 0.16 0.56 0.45]
# best Node: [0.55 0.1  0.68 0.51 0.69 0.33 0.8  0.74 0.51]
# best Node: [0.55 0.06 0.79 0.52 0.27 1.   0.45 0.72 0.18]
# best Node: [0.5  0.21 0.37 0.61 0.78 0.13 0.25 0.33 0.17 0.59]
# best Node: [0.21 0.79 0.39 0.47 0.07 0.45 0.29 0.33 0.92 0.43]
# best Node: [0.19 0.55 0.48 0.26 0.54 0.9  0.93 0.29 0.41 0.66]
# best Node: [0.49 0.96 0.24 0.25 0.49 0.49 0.18 0.65 0.18 0.58]
# best Node: [0.49 0.69 0.41 0.15 0.54 0.12 0.57 0.51 0.88 0.33]
# best Node: [0.35 0.74 0.03 0.23 0.28 0.88 0.59 0.39 0.32 0.01]
# best Node: [0.49 0.29]
# best Node: [0.57 0.5 ]
# best Node: [0.73 0.97]
# best Node: [0.79 0.83]
# best Node: [0.81 0.91]
# best Node: [0.51 0.79 0.2 ]
# best Node: [0.69 0.5  0.48]
# best Node: [0.77 0.38 0.52]
# best Node: [0.77 0.35 0.72]
# best Node: [0.89 0.25 0.96]
# best Node: [0.89 0.21 0.86]
# best Node: [0.5  0.9  0.8  0.09 0.04]
# best Node: [0.85 0.5  0.9  0.64 0.71]
# best Node: [0.9  0.35 0.51 0.38 0.45]
# best Node: [1.   0.15 0.78 0.28 0.91]
# best Node: [0.75 0.07 0.78 0.28 0.91]
# best Node: [0.52 0.13 0.26 0.49 0.21 0.54 0.04]
# best Node: [0.89 0.52 0.74 0.42 0.85 0.94 0.7 ]
# best Node: [0.58 0.62 0.54 0.94 0.25 0.82 0.36]
# best Node: [0.79 0.77 0.97 0.5  0.   0.85 0.18]
# best Node: [0.74 0.71 0.99 0.75 0.39 0.59 0.55]
# best Node: [0.76 0.88 0.69 0.61 0.45 0.87 0.52]
# best Node: [0.5  0.34 0.9  0.61 0.37 1.   0.43 0.82 0.82]
# best Node: [0.16 0.98 0.54 0.5  0.52 0.53 0.48 0.68 0.02]
# best Node: [0.28 0.64 0.84 0.09 0.49 0.96 0.8  0.11 0.09]
# best Node: [0.03 0.82 0.74 0.42 0.73 0.56 0.61 0.56 0.18]
# best Node: [0.49 0.62 0.87 0.93 0.47 0.77 0.14 0.32 0.59 0.93]
# best Node: [0.85 0.5  0.13 0.56 0.44 0.34 0.19 0.57 0.7  0.06]
# best Node: [0.72 0.27 0.86 0.54 0.17 0.77 0.72 0.55 0.14 0.09]
# best Node: [0.63 0.17 0.87 0.63 0.51 0.87 0.88 0.65 0.96 0.25]
# best Node: [0.71 0.13 0.69 0.63 0.69 0.32 0.5  0.45 0.47 0.39]
# best Node: [0.51 0.07 0.64 0.81 0.39 0.58 0.52 0.09 0.79 0.42]
# best Node: [0.51 0.45]
# best Node: [0.49 0.48]
# best Node: [0.26 0.81]
# best Node: [0.15 0.71]
# best Node: [0.12 0.68]
# best Node: [0.5  0.45 0.36]
# best Node: [0.71 0.51 0.41]
# best Node: [0.78 0.2  0.52]
# best Node: [0.77 0.26 0.67]
# best Node: [0.98 0.24 0.76]
# best Node: [0.89 0.24 0.62]
# best Node: [0.5  0.11 0.4  0.68 0.8 ]
# best Node: [0.75 0.51 0.26 0.79 0.59]
# best Node: [0.93 0.71 0.51 0.46 0.97]
# best Node: [0.51 0.76 0.55 0.52 0.39]
# best Node: [0.85 0.63 0.76 0.77 0.55]
# best Node: [0.77 0.76 0.94 0.51 0.5 ]
# best Node: [0.5  0.42 0.61 0.05 0.34 0.58 0.98]
# best Node: [0.44 0.02 0.49 0.23 0.03 0.84 0.87]
# best Node: [0.14 0.05 0.53 0.23 0.87 0.41 0.81]
# best Node: [0.3  0.07 0.6  0.5  0.5  0.63 0.83]
# best Node: [0.51 0.99 0.13 0.94 0.75 0.23 0.37 0.91 0.79]
# best Node: [0.48 0.51 0.38 0.95 0.46 0.36 0.56 0.14 0.57]
# best Node: [0.58 0.54 0.31 0.9  0.13 0.46 0.45 0.61 0.58]
# best Node: [0.5  0.09 0.4  0.28 0.99 0.97 0.84 0.79 1.   0.36]
# best Node: [0.34 0.51 0.02 0.74 0.4  0.04 0.23 0.19 0.87 0.18]
# best Node: [0.09 0.71 0.53 0.61 0.49 0.22 0.79 0.86 0.48 0.4 ]
# best Node: [0.09 0.73 0.29 0.52 0.75 0.6  0.48 0.13 0.28 0.66]
# best Node: [0.13 0.75 0.53 0.91 0.41 0.58 0.28 0.91 0.41 0.58]
# best Node: [0.32 0.69 0.49 0.55 0.4  0.95 0.19 0.54 0.8  0.57]
# best Node: [0.62 0.98 0.42 0.82 0.04 0.7  0.08 0.56 0.3  0.71]
# best Node: [0.5  0.79]
# best Node: [0.6  0.49]
# best Node: [0.54 0.62]
# best Node: [0.56 0.52]
# best Node: [0.52 0.56]
# best Node: [0.5  0.89 0.76]
# best Node: [0.32 0.5  0.98]
# best Node: [0.3  0.13 0.5 ]
# best Node: [0.06 0.24 0.87]
# best Node: [0.15 0.14 0.74]
# best Node: [0.02 0.12 0.84]
# best Node: [0.5  0.24 0.24 0.09 0.72]
# best Node: [0.04 0.25 0.49 0.51 0.22]
# best Node: [0.22 0.41 0.16 0.41 0.52]
# best Node: [0.23 0.02 0.29 0.4  0.31]
# best Node: [0.26 0.21 0.42 0.31 0.31]
# best Node: [0.16 0.28 0.23 0.19 0.27]
# best Node: [0.51 0.31 0.89 0.25 0.07 0.89 0.06]
# best Node: [0.89 0.48 0.3  0.91 0.97 0.1  0.18]
# best Node: [0.76 0.01 0.5  0.4  0.75 0.3  0.51]
# best Node: [0.5  0.83 0.1  0.31 0.59 0.44 0.03 0.52 0.72]
# best Node: [0.12 0.12 0.51 0.96 0.43 0.28 0.45 0.17 0.49]
# best Node: [0.26 0.42 0.45 0.62 0.43 0.64 0.5  0.32 0.29]
# best Node: [0.49 0.19 0.08 0.12 0.05 0.72 0.81 0.05 0.18 0.34]
# best Node: [0.73 0.5  0.68 0.59 0.87 0.74 0.97 0.22 0.07 0.68]
# best Node: [0.64 0.19 0.52 0.27 0.85 0.81 0.02 0.45 0.91 0.24]
# best Node: [0.99 0.33 0.18 0.9  0.49 0.65 0.42 0.61 0.44 0.39]
# best Node: [0.63 0.31 0.04 0.72 0.79 0.52 0.67 0.4  0.6  0.38]
# best Node: [0.59 0.2  0.12 0.86 0.74 0.3  0.32 0.62 0.94 0.47]
# best Node: [0.73 0.35 0.27 0.76 0.59 0.62 0.03 0.38 0.29 0.75]
# best Node: [0.51 0.95]
# best Node: [0.97 0.48]
# best Node: [0.75 0.35]
# best Node: [0.68 0.29]
# best Node: [0.8 0.3]
# best Node: [0.79 0.31]
# best Node: [0.5  0.64 0.51]
# best Node: [0.24 0.82 0.11]
# best Node: [0.24 0.73 0.37]
# best Node: [0.42 0.97 0.27]
# best Node: [0.3  0.86 0.27]
# best Node: [0.51 0.54 0.91 0.53 0.77]
# best Node: [0.74 0.62 0.48 0.29 0.3 ]
# best Node: [0.74 0.66 0.89 0.48 0.35]
# best Node: [0.9  0.73 0.98 0.79 0.3 ]
# best Node: [1.   0.89 0.78 0.53 0.15]
# best Node: [0.5  0.64 0.23 0.56 0.89 0.32 0.2 ]
# best Node: [0.39 0.51 0.64 0.43 0.83 0.96 0.65]
# best Node: [0.49 0.61 0.45 0.23 0.45 0.71 0.32]
# best Node: [0.48 0.65 0.2  0.42 0.77 0.67 0.51]
# best Node: [0.5  0.72 0.31 0.24 0.84 0.53 0.03 0.73 0.23]
# best Node: [0.48 0.5  0.02 0.6  0.92 0.4  0.54 0.92 0.51]
# best Node: [0.48 0.42 0.52 0.83 0.28 0.83 0.39 0.07 0.83]
# best Node: [0.06 0.09 0.67 0.16 0.55 0.72 0.62 0.6  0.26]
# best Node: [0.15 0.26 0.81 0.14 0.16 0.47 0.6  0.91 0.62]
# best Node: [0.5  0.96 0.2  0.08 0.66 0.57 0.37 0.34 0.2  0.43]
# best Node: [0.88 0.52 0.69 0.06 0.16 0.78 0.52 0.48 0.82 0.3 ]
# best Node: [0.97 0.61 0.65 0.5  0.4  0.56 0.5  0.34 0.36 0.55]
# best Node: [0.51 0.27]
# best Node: [1.   0.48]
# best Node: [0.76 0.87]
# best Node: [0.88 0.84]
# best Node: [0.85 0.88]
# best Node: [0.51 0.94 0.47]
# best Node: [0.22 0.85 0.58]
# best Node: [0.24 0.86 0.77]
# best Node: [0.38 0.92 0.74]
# best Node: [0.33 0.9  0.7 ]
# best Node: [0.5  0.14 0.49 0.8  0.14]
# best Node: [0.15 0.49 1.   0.06 0.25]
# best Node: [0.39 0.14 0.74 0.51 0.44]
# best Node: [0.25 0.37 0.93 0.28 0.98]
# best Node: [0.09 0.24 0.8  0.1  0.77]
# best Node: [0.08 0.07 0.8  0.09 0.89]
# best Node: [0.29 0.06 0.82 0.31 0.74]
# best Node: [0.49 0.   0.25 0.64 0.46 0.2  0.11]
# best Node: [0.54 0.49 0.33 0.42 0.48 0.13 0.52]
# best Node: [0.87 0.64 0.5  0.27 0.31 0.5  0.91]
# best Node: [0.85 0.62 0.79 0.47 0.38 0.69 0.75]
# best Node: [0.77 0.95 0.71 0.73 0.89 0.49 0.54]
# best Node: [0.84 0.95 0.69 0.58 0.47 0.79 0.54]
# best Node: [0.71 0.63 0.62 0.85 0.32 0.71 0.57]
# best Node: [0.95 0.86 0.36 0.82 0.64 0.53 0.77]
# best Node: [0.5  0.39 0.6  0.55 0.45 0.33 0.13 0.99 0.81]
# best Node: [0.46 0.51 0.4  0.51 0.15 0.61 0.36 0.89 0.08]
# best Node: [0.09 0.99 0.51 0.3  0.1  0.18 0.99 0.25 0.65]
# best Node: [0.18 0.76 0.09 0.27 0.26 0.57 0.48 0.53 0.6 ]
# best Node: [0.75 0.73 0.09 0.12 0.42 0.32 0.87 0.47 0.58]
# best Node: [0.51 0.28 0.94 0.54 0.14 0.05 0.13 0.21 0.22 0.98]
# best Node: [0.8  0.38 0.48 0.94 0.05 0.64 0.53 0.71 0.86 0.44]
# best Node: [0.4  0.31 0.64 0.57 0.35 0.48 0.6  0.6  0.81 0.55]
# best Node: [0.38 0.38 0.99 0.93 0.31 0.62 0.49 0.72 0.8  0.19]
# best Node: [0.5  0.07]
# best Node: [0.59 0.5 ]
# best Node: [0.74 0.83]
# best Node: [0.87 0.95]
# best Node: [0.94 0.99]
# best Node: [0.51 0.16 0.93]
# best Node: [0.89 0.25 0.77]
# best Node: [0.87 0.29 0.79]
# best Node: [0.76 0.39 0.87]
# best Node: [0.5  0.6  0.87 0.45 0.9 ]
# best Node: [0.94 0.51 0.75 0.06 0.18]
# best Node: [0.79 0.29 0.26 0.08 0.05]
# best Node: [0.51 0.03 0.29 0.91 0.37 0.47 0.19]
# best Node: [0.39 0.5  0.98 0.83 0.7  0.1  0.74]
# best Node: [0.33 0.9  0.48 0.6  0.29 0.75 0.45]
# best Node: [0.22 0.63 0.77 0.53 0.67 0.64 0.35]
# best Node: [0.05 0.77 0.79 0.39 0.51 0.33 0.61]
# best Node: [0.19 0.92 0.53 0.08 0.52 0.24 0.72]
# best Node: [0.51 0.14 0.75 0.33 0.45 0.52 0.13 0.6  0.3 ]
# best Node: [0.96 0.5  0.58 0.42 0.87 0.83 0.39 0.3  0.3 ]
# best Node: [0.64 0.44 0.82 0.48 0.72 0.42 0.72 0.39 0.53]
# best Node: [0.34 0.29 0.87 0.97 0.87 0.22 0.71 0.63 0.11]
# best Node: [0.49 0.44 0.04 0.19 0.32 0.12 0.33 0.24 0.02 0.13]
# best Node: [1.   0.54 0.48 0.78 0.57 0.17 0.5  0.82 0.09 0.19]
# best Node: [0.78 0.51 0.1  0.83 0.78 0.49 0.24 0.54 0.16 0.9 ]
# best Node: [0.93 0.62 0.37 0.94 0.65 0.64 0.59 0.9  0.12 0.62]
# best Node: [0.84 0.83 0.07 0.83 0.65 0.42 0.94 0.41 0.08 0.56]
# best Node: [0.86 0.54 0.36 0.29 0.85 0.75 0.92 0.49 0.14 0.85]
# best Node: [0.72 0.39 0.52 0.55 0.73 0.72 0.81 0.33 0.07 0.19]
# best Node: [0.48 0.63]
# best Node: [0.15 0.49]
# best Node: [0.24 0.26]
# best Node: [0.06 0.24]
# best Node: [0.5  0.02 0.9 ]
# best Node: [0.94 0.49 0.89]
# best Node: [0.73 0.64 0.53]
# best Node: [0.75 0.66 0.04]
# best Node: [0.55 0.66 0.25]
# best Node: [0.62 0.64 0.08]
# best Node: [0.52 0.61 0.17]
# best Node: [0.64 0.6  0.07]
# best Node: [0.5  0.02 0.01 0.04 0.42]
# best Node: [0.83 0.51 0.45 0.1  0.44]
# best Node: [0.81 0.03 0.49 0.56 0.07]
# best Node: [0.6  0.06 0.8  0.46 0.26]
# best Node: [0.88 0.46 0.64 0.59 0.49]
# best Node: [0.96 0.24 0.8  0.71 0.9 ]
# best Node: [0.92 0.46 0.73 0.79 0.76]
# best Node: [0.59 0.27 0.74 0.92 0.51]
# best Node: [0.51 0.14 0.38 0.61 0.77 0.15 0.54]
# best Node: [0.43 0.49 0.42 0.43 0.21 0.35 0.68]
# best Node: [0.23 0.68 0.51 0.52 0.3  0.5  0.04]
# best Node: [0.45 0.78 0.74 0.48 0.34 0.46 0.69]
# best Node: [0.24 0.64 0.83 0.38 0.26 0.74 0.53]
# best Node: [0.29 0.65 0.81 0.45 0.19 0.45 0.46]
# best Node: [0.49 0.73 0.6  0.82 0.29 0.29 0.8  0.84 0.67]
# best Node: [0.57 0.82 0.48 0.36 0.77 0.19 0.95 0.51 0.41]
# best Node: [0.95 0.77 0.4  0.24 0.51 0.95 0.74 0.5  0.33]
# best Node: [0.61 0.81 0.17 0.02 0.77 0.4  0.48 0.71 0.64]
# best Node: [0.73 0.65 0.29 0.39 0.54 0.36 0.85 0.48 0.79]
# best Node: [0.51 0.79 0.02 0.14 0.26 0.85 0.91 0.5  0.58]
# best Node: [0.42 0.71 0.41 0.41 0.85 0.61 0.64 0.67 0.53]
# best Node: [0.5  0.41 0.99 0.06 0.43 0.35 0.85 0.27 0.05 0.1 ]
# best Node: [0.52 0.57 0.78 0.72 0.47 0.38 0.44 0.59 0.54 0.12]
# best Node: [0.92 0.82 0.63 0.52 0.82 0.44 0.75 0.3  0.17 0.16]
# best Node: [0.81 0.95 0.71 0.81 0.66 0.36 0.46 0.51 0.44 0.55]
# best Node: [0.62 0.97 0.73 0.77 0.46 0.55 0.47 0.46 0.03 0.74]
# best Node: [0.79 0.69 0.33 0.5  0.77 0.15 0.54 0.18 0.31 0.26]
# best Node: [0.49 0.8  0.72 0.76 0.52 0.08 0.6  0.29 0.33 0.19]
# best Node: [0.49 0.84]
# best Node: [0.91 0.49]
# best Node: [0.76 0.16]
# best Node: [0.56 0.25]
# best Node: [0.63 0.44]
# best Node: [0.65 0.38]
# best Node: [0.51 0.18 0.69]
# best Node: [0.15 0.48 0.77]
# best Node: [0.32 0.38 0.75]
# best Node: [0.39 0.33 0.88]
# best Node: [0.29 0.39 0.94]
# best Node: [0.49 0.25 0.84 0.01 0.6 ]
# best Node: [0.91 0.51 0.86 0.99 0.5 ]
# best Node: [0.81 0.57 0.53 0.7  0.6 ]
# best Node: [0.98 0.6  0.36 0.52 0.98]
# best Node: [0.75 0.53 0.17 0.39 0.93]
# best Node: [0.83 0.78 0.06 0.51 0.85]
# best Node: [0.49 0.95 0.35 0.9  0.96 0.48 0.8 ]
# best Node: [0.98 0.48 0.62 0.72 0.78 0.25 0.1 ]
# best Node: [0.72 0.68 0.93 0.53 0.41 0.07 0.14]
# best Node: [0.5  0.62 0.76 0.48 0.74 0.72 0.87 0.11 0.18]
# best Node: [0.42 0.48 0.57 0.96 0.5  0.01 0.55 0.87 0.18]
# best Node: [0.22 0.67 0.49 0.2  0.48 0.63 0.09 0.85 0.24]
# best Node: [0.19 0.53 0.51 0.49 0.37 0.23 0.26 0.53 0.54]
# best Node: [0.06 0.55 0.67 0.84 0.27 0.5  0.44 0.38 0.5 ]
# best Node: [0.44 0.55 0.79 0.91 0.14 0.86 0.57 0.61 0.19]
# best Node: [0.36 0.59 0.6  0.48 0.04 0.54 0.33 0.54 0.47]
# best Node: [0.51 0.65 0.69 0.46 0.07 0.48 0.3  0.7  0.74 0.15]
# best Node: [0.92 0.29 0.57 0.16 0.47 0.02 0.62 0.45 0.32 0.57]
# best Node: [0.97 0.4  0.62 0.37 0.05 0.47 0.02 0.49 0.34 0.73]
# best Node: [0.79 0.18 0.7  0.2  0.32 0.38 0.37 0.27 0.84 0.56]
# best Node: [0.83 0.18 0.68 0.26 0.54 0.81 0.57 0.25 0.75 0.55]
# best Node: [0.9  0.54 0.83 0.24 0.52 0.55 0.44 0.42 0.1  0.71]

# %%
# !pip install datasketch
# Out:
# Requirement already satisfied: datasketch in /usr/local/lib/python3.10/dist-packages (1.6.5)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from datasketch) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from datasketch) (1.13.1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors, KDTree
from datasketch import MinHash, MinHashLSH

# Function to create a MinHash object from numerical data
def create_minhash(data_point, num_perm=128):
    m = MinHash(num_perm=num_perm)
    for feature in data_point:
        m.update(str(feature).encode('utf8'))
    return m

# Generate random 2D data
N = 1000  # number of points
D = 2  # dimensions
data = np.random.rand(N, D)

# KD-tree
nn_kdtree = KDTree(data, leaf_size=30)

# LSH setup
lsh = MinHashLSH(threshold=0.5, num_perm=128)
minhashes = {}
for i, point in enumerate(data):
    minhash = create_minhash(point)
    minhashes[i] = minhash
    lsh.insert(f"data_{i}", minhash)

# Query point and its MinHash
query_point = np.random.rand(1, D)[0]
query_minhash = create_minhash(query_point)
result = lsh.query(query_minhash)

# Results and visualization
print("Approximate Neighbors' Indices:", result)

# KD-tree query
_, kd_indices = nn_kdtree.query([query_point], k=10)

# Visualize data points
plt.figure(figsize=(10, 6))
plt.scatter(data[:, 0], data[:, 1], alpha=0.5, label='Data points')
plt.scatter(data[kd_indices[0], 0], data[kd_indices[0], 1], color='g', label='KD-tree Neighbors')
plt.scatter(query_point[0], query_point[1], color='red', label='Query Point')

# Highlight LSH results
for idx in result:
    idx = int(idx.split("_")[1])
    plt.scatter(data[idx, 0], data[idx, 1], color='yellow', edgecolor='black', label='LSH Neighbors' if 'LSH Neighbors' not in plt.gca().get_legend_handles_labels()[1] else "")

plt.legend()
plt.show()
# Out:
# Approximate Neighbors' Indices: []

# %%
import numpy as np
import matplotlib.pyplot as plt

# We'll need to modify your MyNode class to store the splitting hyperplane and to reference the parent
class MyNode:
    def __init__(self, _id, data, axis, idx, parent=None):
        self._id = _id
        self.data = data
        self.axis = axis
        self.idx = idx
        self.parent = parent
        self.left = None
        self.right = None

# Calculate Euclidean distance
def distance(point1, point2):
    return np.sqrt(np.sum((point1 - point2) ** 2))

# Custom KD-tree implementation
from math import floor
import numpy as np
import pandas as pd



class KD_Tree:
    def __init__(self, data):
        self.data = data
        self.tree = None

    def _build(self, points, depth):
        k = len(points.columns)
        _axis = depth % k
        _column = points.columns[_axis]

        if len(points) == 0:
            return None

        objects_list = points.sort_values(by=[_column], ascending=True)

        if len(objects_list) % 2 == 0:
            median_idx = int((len(objects_list) / 2))
        else:
            median_idx = floor((len(objects_list) / 2))

        node = MyNode(_id=round(objects_list.iloc[median_idx][_column], 3),
                      data=objects_list.iloc[median_idx],
                      axis=_column,
                      idx=median_idx)

        if len(objects_list) <= 40:
            return node  # Stop further branching if number of data points is 40 or fewer

        node.left = self._build(objects_list.iloc[0:median_idx], depth + 1)
        node.right = self._build(objects_list.iloc[median_idx + 1:], depth + 1)

        return node

    def build(self):
        self.tree = self._build(self.data, depth=0)

    def _nearest(self, query, node, best_node, best_distance):
        if not node:
            return best_node, best_distance

        d = distance(query.values[0], node.data.values)

        if d < best_distance:
            best_node = node
            best_distance = d
            print("best Node: {}".format(best_node.data.values))

        if query[node.axis].values[0] < node.data[node.axis]:
            good_side = node.left
            bad_side = node.right
        else:
            bad_side = node.left
            good_side = node.right

        best_node, best_distance = self._nearest(query, good_side, best_node, best_distance)

        if abs(node.data[node.axis] - query[node.axis].values[0]) < best_distance:
            best_node, best_distance = self._nearest(query, bad_side, best_node, best_distance)

        return best_node, best_distance

    def get_nn(self, query):
        return self._nearest(query, self.tree, None, np.inf)


# Function to visualize the KD-tree partitions
def visualize_tree(node, min_x, max_x, min_y, max_y):
    if node is None:
        return

    # Determine the splitting axis
    axis = node.axis
    value = node.data[axis]

    # Draw the splitting line
    if axis == 'x':
        plt.axvline(value, ymin=min_y, ymax=max_y, color='black')
        visualize_tree(node.left, min_x, value, min_y, max_y)
        visualize_tree(node.right, value, max_x, min_y, max_y)
    elif axis == 'y':
        plt.axhline(value, xmin=min_x, xmax=max_x, color='black')
        visualize_tree(node.left, min_x, max_x, min_y, value)
        visualize_tree(node.right, min_x, max_x, value, max_y)

# Generate a 2D dataset
np.random.seed(42)
N = 100  # Number of points
data = pd.DataFrame(np.random.rand(N, 2), columns=['x', 'y'])

# Instantiate and build the KD-tree
kd_tree = KD_Tree(data)
kd_tree.build()

# Define the bounds of the plot
min_x, max_x = 0, 1
min_y, max_y = 0, 1

# Plot the dataset and the partitions
plt.figure(figsize=(12, 8))
plt.scatter(data['x'], data['y'], s=50, label='Data Points')

# Plot the partitions
visualize_tree(kd_tree.tree, min_x, max_x, min_y, max_y)

plt.xlim(min_x, max_x)
plt.ylim(min_y, max_y)
plt.legend()
plt.title('KD-tree Partitions')
plt.show()
